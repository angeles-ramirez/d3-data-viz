# %%
# Import the Twython class
import tweepy
import json
import pandas as pd 
import os
import requests

# Load credentials from json file:
# os.chdir('C:/Users/angy4/BootCamp-HW/Twitter API/Angeles') #Folder Location
tHash = "https://twitter.com/hashtag/"
ht = "bitcoin"
url = tHash + ht

request = requests.get(url).json


# python_tweets = Twython(credentials['CONSUMER_KEY'], credentials['CONSUMER_SECRET'])
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-28-dfe4ebffecb5> in <module>
#      15
#      16 with open("twitter_credentials.json", "r") as file:
# ---> 17     creds = json.load(file)
#      18
#      19 # python_tweets = Twython(credentials['CONSUMER_KEY'], credentials['CONSUMER_SECRET'])
#
# ~\Anaconda3\lib\json\__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
# --> 296         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#     297
#     298
#
# ~\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
# ...

# %%
#Set up Twitter Authentication
auth = tweepy.OAuthHandler(creds['CONSUMER_KEY'], creds['CONSUMER_SECRET'])
auth.set_access_token(creds['ACCESS_TOKEN'], creds['ACCESS_SECRET'])

api = tweepy.API(auth)

listTweets = []
keyword = 'trump'
NumTweets = 500
StartDt = '2019-11-09'
EndDt = '2019-11-17'

def get_tweets(listTweets, keyword, StartDt, EndDt, NumTweets):
    # Iterate through all tweets containing the given word, api search mode
    for tweet in tweepy.Cursor(api.search, q=keyword, since=StartDt, until=EndDt).items(NumTweets):
        # Add tweets in this format
        dict_ = {'Screen_Name': tweet.user.screen_name,
                'User_Name': tweet.user.name,
                'Tweet_Created_At': str(tweet.created_at),
                'Tweet_Text': tweet.text,
                'Hashtags': tweet.entities.get('hashtags'),
                'User_Location': str(tweet.user.location),
                'Tweet_Coordinates': str(tweet.coordinates),
                'Retweet_Count': str(tweet.retweet_count),
                'Retweeted': str(tweet.retweeted),
                'Favorite_Count': str(tweet.favorite_count),
                'Favorited': str(tweet.favorited),
                'Replied': str(tweet.in_reply_to_status_id_str)
                }
        listTweets.append(dict_)   
    return listTweets
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-1c839c277b25> in <module>
#       1 #Set up Twitter Authentication
# ----> 2 auth = tweepy.OAuthHandler(creds['CONSUMER_KEY'], creds['CONSUMER_SECRET'])
#       3 auth.set_access_token(creds['ACCESS_TOKEN'], creds['ACCESS_SECRET'])
#       4
#       5 api = tweepy.API(auth)
#
# NameError: name 'creds' is not defined

# %%
get_tweets(listTweets, keyword, StartDt, EndDt, NumTweets)
# Out:
# [{'Screen_Name': 'jarowell',
#   'User_Name': 'Al Rowell',
#   'Tweet_Created_At': '2019-11-16 23:59:59',
#   'Tweet_Text': 'RT @fawfulfan: Trump just pardoned an Army lieutenant who ordered his troops to fire on unarmed Afghani civilians driving past on a motorcy…',
#   'Hashtags': [],
#   'User_Location': 'South Georgia, USA',
#   'Tweet_Coordinates': 'None',
#   'Retweet_Count': '2200',
#   'Retweeted': 'False',
#   'Favorite_Count': '0',
#   'Favorited': 'False',
#   'Replied': 'None'},
#  {'Screen_Name': 'RedwoodGirl',
#   'User_Name': 'RedwoodWitch🌹🔥 #WheresTheHousing #MedicareForAll',
#   'Tweet_Created_At': '2019-11-16 23:59:59',
#   'Tweet_Text': "@ToggleWaffle @TwinklingTania @IronStache Nope, Bernie's the one. He's not just an anti-Trump but an anti-Reagan, w… https://t.co/LpNkPN5fBi",
#   'Hashtags': [],
#   'User_Location': 'Chico, CA',
#   'Tweet_Coordinates': 'None',
#   'Retweet_Count': '1',
#   'Retweeted': 'False',
#   'Favorite_Count': '23',
# ...

# %%
df = pd.DataFrame.from_dict(listTweets, orient='columns')

# %%
df.sort_values(by=['Tweet_Created_At'])

export_csv = df.to_csv (r'/Users/macbook/Desktop/Data-Program-Files/Group-Projects/Project-3/tweet_samples.csv', index = None, header=True)
