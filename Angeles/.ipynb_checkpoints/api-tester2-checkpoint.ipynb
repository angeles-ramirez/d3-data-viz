# %%
from pprint import pprint
import json
import pandas as pd
from pandas.io.json import json_normalize
import numpy as np
import requests, json, csv
from twython import Twython, TwythonStreamer
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler, Stream, API, Cursor
import twitter_credentials

# %%
CONSUMER_KEY = 'Hgr2TlRxnBQwANqQv6lbAPdQK'
CONSUMER_SECRET = 'OjAgBxBOWOUcgAClfuw00KITmy1asnWwVC4DAdOtdDBtOZbtQ2'
ACCESS_TOKEN = '1195204217041903616-Xk76aygVlQ2NjY15dZ5J6SVoGYpHrI'
ACCESS_SECRET= 'r3dkhipY2D3DsqcHGPEUCtsq1CjpbrRzu18odz33pzyxJ'

# %%
#Twython instance
twitter = Twython(CONSUMER_KEY, CONSUMER_SECRET,
                  access_token = ACCESS_TOKEN, ACCESS_SECRET)

# %%
# twitter.verify_credentials()

# %%
#"q" for query --- required when searching
twitter.search(q='python', 
              lang='en',
              result_type='recent',
              )
# Out:
# {'statuses': [{'created_at': 'Thu Nov 21 09:08:52 +0000 2019',
#    'id': 1197441736789970945,
#    'id_str': '1197441736789970945',
#    'text': 'RT @motherofnodejs: Internships be like #programming #coding #programmer #javascript #coder #php #java #programminglife #developer #python…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'programming', 'indices': [40, 52]},
#      {'text': 'coding', 'indices': [53, 60]},
#      {'text': 'programmer', 'indices': [61, 72]},
#      {'text': 'javascript', 'indices': [73, 84]},
#      {'text': 'coder', 'indices': [85, 91]},
#      {'text': 'php', 'indices': [92, 96]},
#      {'text': 'java', 'indices': [97, 102]},
#      {'text': 'programminglife', 'indices': [103, 119]},
#      {'text': 'developer', 'indices': [120, 130]},
#      {'text': 'python', 'indices': [131, 138]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'motherofnodejs',
#       'name': 'Mother Of Node.js',
#       'id': 1115905374190800896,
#       'id_str': '1115905374190800896',
#       'indices': [3, 18]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://github.com/AlFalahTaieb" rel="nofollow">Js_100_Day_Code</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 885513434569355265,
#     'id_str': '885513434569355265',
#     'name': 'JSBot',
#     'screen_name': 'Taieb_Bot',
#     'location': 'Raspberry PI',
#     'description': 'I retweet all about #100DaysOfCode #Javascript and my mother country #Tunisia created by @Filsdelarabe',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 521,
#     'friends_count': 1,
#     'listed_count': 21,
#     'created_at': 'Thu Jul 13 14:57:09 +0000 2017',
#     'favourites_count': 85521,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 159257,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/885513954818220033/gf3Ci4dO_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/885513954818220033/gf3Ci4dO_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/885513434569355265/1499969529',
#     'profile_link_color': 'ABB8C2',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Nov 15 10:49:42 +0000 2019',
#     'id': 1195292787320741888,
#     'id_str': '1195292787320741888',
#     'text': 'Internships be like #programming #coding #programmer #javascript #coder #php #java #programminglife #developer… https://t.co/deU6oMUYFH',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'programming', 'indices': [20, 32]},
#       {'text': 'coding', 'indices': [33, 40]},
#       {'text': 'programmer', 'indices': [41, 52]},
#       {'text': 'javascript', 'indices': [53, 64]},
#       {'text': 'coder', 'indices': [65, 71]},
#       {'text': 'php', 'indices': [72, 76]},
#       {'text': 'java', 'indices': [77, 82]},
#       {'text': 'programminglife', 'indices': [83, 99]},
#       {'text': 'developer', 'indices': [100, 110]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/deU6oMUYFH',
#        'expanded_url': 'https://twitter.com/i/web/status/1195292787320741888',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [112, 135]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://ifttt.com" rel="nofollow">IFTTT</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1115905374190800896,
#      'id_str': '1115905374190800896',
#      'name': 'Mother Of Node.js',
#      'screen_name': 'motherofnodejs',
#      'location': '404',
#      'description': '#programmer',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 272,
#      'friends_count': 1,
#      'listed_count': 3,
#      'created_at': 'Wed Apr 10 09:12:28 +0000 2019',
#      'favourites_count': 1,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 4514,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1115906484125208577/pO_Ry4yJ_normal.png',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1115906484125208577/pO_Ry4yJ_normal.png',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 33,
#     'favorite_count': 34,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 33,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Nov 21 09:08:51 +0000 2019',
#    'id': 1197441734957043712,
#    'id_str': '1197441734957043712',
#    'text': "@HarridenceGary @SocialistChris @JanmRees1 Good to see we share a love of Monty Python. I'm keeping Spiny Norman away for now 😁",
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'HarridenceGary',
#       'name': 'Gary Harridence',
#       'id': 890215471236120576,
#       'id_str': '890215471236120576',
#       'indices': [0, 15]},
#      {'screen_name': 'SocialistChris',
#       'name': 'Chris Furlong',
#       'id': 3263305846,
#       'id_str': '3263305846',
#       'indices': [16, 31]},
#      {'screen_name': 'JanmRees1',
#       'name': 'Jan Rees🌹#VoteLabour #GTTO#JC4PM🏴\U000e0067\U000e0062\U000e0077\U000e006c\U000e0073\U000e007f',
#       'id': 706541202078879744,
#       'id_str': '706541202078879744',
#       'indices': [32, 42]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': 1197275781271040000,
#    'in_reply_to_status_id_str': '1197275781271040000',
#    'in_reply_to_user_id': 890215471236120576,
#    'in_reply_to_user_id_str': '890215471236120576',
#    'in_reply_to_screen_name': 'HarridenceGary',
#    'user': {'id': 1098975481662267394,
#     'id_str': '1098975481662267394',
#     'name': 'Dinsdale Piranha',
#     'screen_name': 'DinsdalePiranh3',
#     'location': '',
#     'description': 'I beg to dream and differ from their hollow lies.....\nTrue Labour. For the many..... JC4PM',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 137,
#     'friends_count': 347,
#     'listed_count': 0,
#     'created_at': 'Fri Feb 22 15:59:07 +0000 2019',
#     'favourites_count': 1951,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 1484,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1099068207745384448/Jus4Vbp0_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1099068207745384448/Jus4Vbp0_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1098975481662267394/1551047481',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Nov 21 09:08:44 +0000 2019',
#    'id': 1197441706561540096,
#    'id_str': '1197441706561540096',
#    'text': 'RT @Deep_In_Depth: 8 Neural Network Compression Techniques For ML Developers https://t.co/Vp54tKKFJD #DeepLearning #MachineLearning #Artifi…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'DeepLearning', 'indices': [101, 114]},
#      {'text': 'MachineLearning', 'indices': [115, 131]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Deep_In_Depth',
#       'name': 'Deep_In_Depth',
#       'id': 861861525883158528,
#       'id_str': '861861525883158528',
#       'indices': [3, 17]}],
#     'urls': [{'url': 'https://t.co/Vp54tKKFJD',
#       'expanded_url': 'https://buff.ly/349K2co',
#       'display_url': 'buff.ly/349K2co',
#       'indices': [77, 100]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://www.wiomax.com/cn" rel="nofollow">wiomax_cn2</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 4557203427,
#     'id_str': '4557203427',
#     'name': 'WioNavi',
#     'screen_name': 'wiomax_cn',
#     'location': 'United States',
#     'description': 'Focus on future #urbanmobility, #sharedmobility #smartmobility and #transportation.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 2431,
#     'friends_count': 929,
#     'listed_count': 1319,
#     'created_at': 'Mon Dec 21 13:18:30 +0000 2015',
#     'favourites_count': 7,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 54518,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/756157098627506177/Y74zY208_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/756157098627506177/Y74zY208_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4557203427/1451874975',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Nov 21 08:00:22 +0000 2019',
#     'id': 1197424500528336896,
#     'id_str': '1197424500528336896',
#     'text': '8 Neural Network Compression Techniques For ML Developers https://t.co/Vp54tKKFJD #DeepLearning #MachineLearning… https://t.co/j5CqhCwfV7',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'DeepLearning', 'indices': [82, 95]},
#       {'text': 'MachineLearning', 'indices': [96, 112]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/Vp54tKKFJD',
#        'expanded_url': 'https://buff.ly/349K2co',
#        'display_url': 'buff.ly/349K2co',
#        'indices': [58, 81]},
#       {'url': 'https://t.co/j5CqhCwfV7',
#        'expanded_url': 'https://twitter.com/i/web/status/1197424500528336896',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [114, 137]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 861861525883158528,
#      'id_str': '861861525883158528',
#      'name': 'Deep_In_Depth',
#      'screen_name': 'Deep_In_Depth',
#      'location': 'Digne-les-Bains, France',
#      'description': 'Deep Learning, Machine Learning, Data Science & AI news \n#DeepLearning #MachineLearning #NeuralNetworks #DataScience #DataMining #AI',
#      'url': 'https://t.co/SwN0QkN0k3',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/SwN0QkN0k3',
#          'expanded_url': 'https://www.linkedin.com/in/eric-feuilleaubois-ph-d-43ab0925/',
#          'display_url': 'linkedin.com/in/eric-feuill…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 5965,
#      'friends_count': 5393,
#      'listed_count': 109,
#      'created_at': 'Tue May 09 08:32:55 +0000 2017',
#      'favourites_count': 1461,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 17999,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/861866967493431296/PIjaSD4g_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/861866967493431296/PIjaSD4g_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/861861525883158528/1494997363',
#      'profile_link_color': '981CEB',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 5,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 5,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Nov 21 09:08:44 +0000 2019',
#    'id': 1197441702879023105,
#    'id_str': '1197441702879023105',
#    'text': "Monty Python wasn't funny #StartAnArgumentIn4Words",
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'StartAnArgumentIn4Words',
#       'indices': [26, 50]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 27239477,
#     'id_str': '27239477',
#     'name': "🦇🦇🦇I'm Batman🦇🦇🦇",
#     'screen_name': 'mbro1',
#     'location': 'Middlesbrough',
#     'description': '@Boro #UTB #WWE #NXT #AEW #RikMayall #MentalHealthAwareness',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 761,
#     'friends_count': 812,
#     'listed_count': 12,
#     'created_at': 'Sat Mar 28 14:47:16 +0000 2009',
#     'favourites_count': 8060,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 8219,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1177339952234938369/GwSlrjF5_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1177339952234938369/GwSlrjF5_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/27239477/1537209891',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Nov 21 09:08:40 +0000 2019',
#    'id': 1197441686324076544,
#    'id_str': '1197441686324076544',
#    'text': 'RT @motherofnodejs: Internships be like #programming #coding #programmer #javascript #coder #php #java #programminglife #developer #python…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'programming', 'indices': [40, 52]},
#      {'text': 'coding', 'indices': [53, 60]},
#      {'text': 'programmer', 'indices': [61, 72]},
#      {'text': 'javascript', 'indices': [73, 84]},
#      {'text': 'coder', 'indices': [85, 91]},
#      {'text': 'php', 'indices': [92, 96]},
#      {'text': 'java', 'indices': [97, 102]},
#      {'text': 'programminglife', 'indices': [103, 119]},
#      {'text': 'developer', 'indices': [120, 130]},
#      {'text': 'python', 'indices': [131, 138]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'motherofnodejs',
#       'name': 'Mother Of Node.js',
#       'id': 1115905374190800896,
#       'id_str': '1115905374190800896',
#       'indices': [3, 18]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1158859679658909696,
#     'id_str': '1158859679658909696',
#     'name': '_Godswill_',
#     'screen_name': 'gemzee3',
#     'location': 'Lagos',
#     'description': "Generic human, with access to social media || 𝕀'𝕞 𝕤𝕚𝕞𝕡𝕝𝕖 𝕪𝕠𝕦 𝕗𝕠𝕝𝕝𝕠𝕨 𝕞𝕖, 𝕚 𝕗𝕠𝕝𝕝𝕠𝕨 𝕓𝕒𝕔𝕜 𝔸𝕊𝔸ℙ!",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 2640,
#     'friends_count': 2673,
#     'listed_count': 0,
#     'created_at': 'Tue Aug 06 21:57:32 +0000 2019',
#     'favourites_count': 7749,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 1422,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1170380026807771137/Q5Su4m18_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1170380026807771137/Q5Su4m18_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1158859679658909696/1570243945',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Nov 15 10:49:42 +0000 2019',
#     'id': 1195292787320741888,
#     'id_str': '1195292787320741888',
#     'text': 'Internships be like #programming #coding #programmer #javascript #coder #php #java #programminglife #developer… https://t.co/deU6oMUYFH',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'programming', 'indices': [20, 32]},
#       {'text': 'coding', 'indices': [33, 40]},
#       {'text': 'programmer', 'indices': [41, 52]},
#       {'text': 'javascript', 'indices': [53, 64]},
#       {'text': 'coder', 'indices': [65, 71]},
#       {'text': 'php', 'indices': [72, 76]},
#       {'text': 'java', 'indices': [77, 82]},
#       {'text': 'programminglife', 'indices': [83, 99]},
#       {'text': 'developer', 'indices': [100, 110]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/deU6oMUYFH',
#        'expanded_url': 'https://twitter.com/i/web/status/1195292787320741888',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [112, 135]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://ifttt.com" rel="nofollow">IFTTT</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1115905374190800896,
#      'id_str': '1115905374190800896',
#      'name': 'Mother Of Node.js',
#      'screen_name': 'motherofnodejs',
#      'location': '404',
#      'description': '#programmer',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 272,
#      'friends_count': 1,
#      'listed_count': 3,
#      'created_at': 'Wed Apr 10 09:12:28 +0000 2019',
#      'favourites_count': 1,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 4514,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1115906484125208577/pO_Ry4yJ_normal.png',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1115906484125208577/pO_Ry4yJ_normal.png',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 33,
#     'favorite_count': 34,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 33,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Nov 21 09:08:34 +0000 2019',
#    'id': 1197441661569314816,
#    'id_str': '1197441661569314816',
#    'text': 'RT @martinfleis: Let me introduce you to my new python package - momepy: Urban Morphology Measuring Toolkit. Building on @geopandas, @pysal…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'martinfleis',
#       'name': 'Martin Fleischmann',
#       'id': 883391969447206913,
#       'id_str': '883391969447206913',
#       'indices': [3, 15]},
#      {'screen_name': 'geopandas',
#       'name': 'GeoPandas',
#       'id': 2790503132,
#       'id_str': '2790503132',
#       'indices': [121, 131]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 905075448798998530,
#     'id_str': '905075448798998530',
#     'name': 'Nikola Milojević-Dupont',
#     'screen_name': 'Nikola_MD',
#     'location': 'Berlin, Allemagne',
#     'description': 'PhD candidate at @MCC_Berlin working on: climate change mitigation, machine learning & urban planning 🦚 Steering committee member of @ClimateChangeAI',
#     'url': 'https://t.co/uheCwJUgzf',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/uheCwJUgzf',
#         'expanded_url': 'https://www.mcc-berlin.net/en/about/team/milojevic-dupont-nikola.html',
#         'display_url': 'mcc-berlin.net/en/about/team/…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 362,
#     'friends_count': 1030,
#     'listed_count': 13,
#     'created_at': 'Tue Sep 05 14:29:37 +0000 2017',
#     'favourites_count': 953,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 219,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/951398788182265856/SziVoeFv_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/951398788182265856/SziVoeFv_normal.jpg',
#     'profile_link_color': '1B95E0',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Nov 20 22:29:33 +0000 2019',
#     'id': 1197280847780614150,
#     'id_str': '1197280847780614150',
#     'text': 'Let me introduce you to my new python package - momepy: Urban Morphology Measuring Toolkit. Building on @geopandas,… https://t.co/TJwYupZ5dh',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'geopandas',
#        'name': 'GeoPandas',
#        'id': 2790503132,
#        'id_str': '2790503132',
#        'indices': [104, 114]}],
#      'urls': [{'url': 'https://t.co/TJwYupZ5dh',
#        'expanded_url': 'https://twitter.com/i/web/status/1197280847780614150',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 883391969447206913,
#      'id_str': '883391969447206913',
#      'name': 'Martin Fleischmann',
#      'screen_name': 'martinfleis',
#      'location': 'Glasgow, Scotland',
#      'description': 'Researcher in urban morphology & geographic data science. University of Strathclyde, Glasgow. In Czech as @ctvrtkar.',
#      'url': 'https://t.co/wXhf3H7tEE',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/wXhf3H7tEE',
#          'expanded_url': 'http://martinfleischmann.net',
#          'display_url': 'martinfleischmann.net',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 88,
#      'friends_count': 105,
#      'listed_count': 1,
#      'created_at': 'Fri Jul 07 18:27:12 +0000 2017',
#      'favourites_count': 187,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 131,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/883775382763294721/u0kyrxBg_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/883775382763294721/u0kyrxBg_normal.jpg',
#      'profile_link_color': 'ABB8C2',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': True,
#     'quoted_status_id': 1197216711256223744,
#     'quoted_status_id_str': '1197216711256223744',
#     'quoted_status': {'created_at': 'Wed Nov 20 18:14:41 +0000 2019',
#      'id': 1197216711256223744,
#      'id_str': '1197216711256223744',
#      'text': "Just published in #JOSS_theOJ: 'momepy: Urban Morphology Measuring Toolkit' https://t.co/Ufm2gHFce5",
#      'truncated': False,
#      'entities': {'hashtags': [{'text': 'JOSS_theOJ', 'indices': [18, 29]}],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [{'url': 'https://t.co/Ufm2gHFce5',
#         'expanded_url': 'https://joss.theoj.org/papers/10.21105/joss.01807',
#         'display_url': 'joss.theoj.org/papers/10.2110…',
#         'indices': [76, 99]}]},
#      'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#      'source': '<a href="https://joss.theoj.org" rel="nofollow">Whedon/JOSS</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'user': {'id': 723667033532018689,
#       'id_str': '723667033532018689',
#       'name': 'JOSS',
#       'screen_name': 'JOSS_TheOJ',
#       'location': '',
#       'description': 'The Journal of Open Source Software. The developer friendly software journal. Tweets by: @KMMoerman and Whedon',
#       'url': 'https://t.co/tZnku3QAlM',
#       'entities': {'url': {'urls': [{'url': 'https://t.co/tZnku3QAlM',
#           'expanded_url': 'http://joss.theoj.org/',
#           'display_url': 'joss.theoj.org',
#           'indices': [0, 23]}]},
#        'description': {'urls': []}},
#       'protected': False,
#       'followers_count': 2999,
#       'friends_count': 79,
#       'listed_count': 68,
#       'created_at': 'Sat Apr 23 00:17:20 +0000 2016',
#       'favourites_count': 354,
#       'utc_offset': None,
#       'time_zone': None,
#       'geo_enabled': False,
#       'verified': False,
#       'statuses_count': 432,
#       'lang': None,
#       'contributors_enabled': False,
#       'is_translator': False,
#       'is_translation_enabled': False,
#       'profile_background_color': 'F5F8FA',
#       'profile_background_image_url': None,
#       'profile_background_image_url_https': None,
#       'profile_background_tile': False,
#       'profile_image_url': 'http://pbs.twimg.com/profile_images/723960899120316416/YVpibxGx_normal.jpg',
#       'profile_image_url_https': 'https://pbs.twimg.com/profile_images/723960899120316416/YVpibxGx_normal.jpg',
#       'profile_banner_url': 'https://pbs.twimg.com/profile_banners/723667033532018689/1461440646',
#       'profile_link_color': '1DA1F2',
#       'profile_sidebar_border_color': 'C0DEED',
#       'profile_sidebar_fill_color': 'DDEEF6',
#       'profile_text_color': '333333',
#       'profile_use_background_image': True,
#       'has_extended_profile': False,
#       'default_profile': True,
#       'default_profile_image': False,
#       'following': False,
#       'follow_request_sent': False,
#       'notifications': False,
#       'translator_type': 'none'},
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 2,
#      'favorite_count': 4,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'retweet_count': 13,
#     'favorite_count': 29,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': True,
#    'quoted_status_id': 1197216711256223744,
#    'quoted_status_id_str': '1197216711256223744',
#    'retweet_count': 13,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Nov 21 09:08:25 +0000 2019',
#    'id': 1197441624617504768,
#    'id_str': '1197441624617504768',
#    'text': 'RT @rapidsai: Want to #GPU accelerate #SciPy.Signal to develop #SDR, speech, or audio applications faster with little to no #Python code ch…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'GPU', 'indices': [22, 26]},
#      {'text': 'SciPy', 'indices': [38, 44]},
#      {'text': 'SDR', 'indices': [63, 67]},
#      {'text': 'Python', 'indices': [124, 131]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'rapidsai',
#       'name': 'RAPIDS AI',
#       'id': 1047296373555519488,
#       'id_str': '1047296373555519488',
#       'indices': [3, 12]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://tutorjeh.com" rel="nofollow">example03101991</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1076172179178487809,
#     'id_str': '1076172179178487809',
#     'name': 'ahmad bazzi',
#     'screen_name': 'drahmadbazzi',
#     'location': 'Nice, France',
#     'description': 'Signal Processing Engineer | PhD in Electrical Engineering | #convexoptimization',
#     'url': 'https://t.co/0iqIH9Pclf',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/0iqIH9Pclf',
#         'expanded_url': 'http://www.youtube.com/c/AhmadBazzi',
#         'display_url': 'youtube.com/c/AhmadBazzi',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 527,
#     'friends_count': 204,
#     'listed_count': 22,
#     'created_at': 'Fri Dec 21 17:46:56 +0000 2018',
#     'favourites_count': 3991,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 12183,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1080446324963770368/w2EDnt9K_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1080446324963770368/w2EDnt9K_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1076172179178487809/1545503908',
#     'profile_link_color': 'CE3456',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Tue Nov 19 19:37:48 +0000 2019',
#     'id': 1196875240644546560,
#     'id_str': '1196875240644546560',
#     'text': 'Want to #GPU accelerate #SciPy.Signal to develop #SDR, speech, or audio applications faster with little to no… https://t.co/Cxki0wnt83',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'GPU', 'indices': [8, 12]},
#       {'text': 'SciPy', 'indices': [24, 30]},
#       {'text': 'SDR', 'indices': [49, 53]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/Cxki0wnt83',
#        'expanded_url': 'https://twitter.com/i/web/status/1196875240644546560',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [111, 134]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1047296373555519488,
#      'id_str': '1047296373555519488',
#      'name': 'RAPIDS AI',
#      'screen_name': 'rapidsai',
#      'location': '',
#      'description': 'End to end collection of CUDA accelerated data science libraries built on @apachearrow, scaled with @dask_dev for ETL, ML, graph analytics, and DL preprocessing',
#      'url': 'https://t.co/GJdaTjta7B',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/GJdaTjta7B',
#          'expanded_url': 'http://rapids.ai',
#          'display_url': 'rapids.ai',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 4194,
#      'friends_count': 85,
#      'listed_count': 78,
#      'created_at': 'Wed Oct 03 01:24:48 +0000 2018',
#      'favourites_count': 1665,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 1304,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1049911508296224770/9R5kP6Ql_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1049911508296224770/9R5kP6Ql_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1047296373555519488/1539153317',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 34,
#     'favorite_count': 67,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 34,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Nov 21 09:08:24 +0000 2019',
#    'id': 1197441620125208577,
#    'id_str': '1197441620125208577',
#    'text': 'RT @gp_pulipaka: A Curated Collection of Useful #Python #JavaScript Snippets That You Can Understand in 30 Seconds or Less. #BigData #Analy…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Python', 'indices': [48, 55]},
#      {'text': 'JavaScript', 'indices': [56, 67]},
#      {'text': 'BigData', 'indices': [124, 132]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'gp_pulipaka',
#       'name': 'Dr. GP Pulipaka',
#       'id': 4263007693,
#       'id_str': '4263007693',
#       'indices': [3, 15]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://www.nosite.com" rel="nofollow">ComaBot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 111366242,
#     'id_str': '111366242',
#     'name': 'comatosed',
#     'screen_name': 'Comatose_D',
#     'location': 'Game Grid',
#     'description': "Geekin' out and spinin' tunes.",
#     'url': 'http://t.co/y5GXG9VR07',
#     'entities': {'url': {'urls': [{'url': 'http://t.co/y5GXG9VR07',
#         'expanded_url': 'http://www.mixcloud.com/comatosed/',
#         'display_url': 'mixcloud.com/comatosed/',
#         'indices': [0, 22]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 5607,
#     'friends_count': 5961,
#     'listed_count': 56,
#     'created_at': 'Thu Feb 04 17:32:51 +0000 2010',
#     'favourites_count': 29247,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 42948,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '131516',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/843933230931857408/-l-x_wd1_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/843933230931857408/-l-x_wd1_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/111366242/1488674047',
#     'profile_link_color': '009999',
#     'profile_sidebar_border_color': 'EEEEEE',
#     'profile_sidebar_fill_color': 'EFEFEF',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Nov 20 13:02:12 +0000 2019',
#     'id': 1197138070212169730,
#     'id_str': '1197138070212169730',
#     'text': 'A Curated Collection of Useful #Python #JavaScript Snippets That You Can Understand in 30 Seconds or Less. #BigData… https://t.co/uC97x1mNie',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'Python', 'indices': [31, 38]},
#       {'text': 'JavaScript', 'indices': [39, 50]},
#       {'text': 'BigData', 'indices': [107, 115]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/uC97x1mNie',
#        'expanded_url': 'https://twitter.com/i/web/status/1197138070212169730',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 4263007693,
#      'id_str': '4263007693',
#      'name': 'Dr. GP Pulipaka',
#      'screen_name': 'gp_pulipaka',
#      'location': 'Redondo Beach, CA',
#      'description': 'Chief Data Scientist @AccentureTech | Global Premier Speaker | PostDoc CS, PhD | Top Data Science Influencer | Bestselling Author | Views are my own',
#      'url': 'https://t.co/CHWoaV475R',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/CHWoaV475R',
#          'expanded_url': 'https://www.linkedin.com/in/dr-ganapathi-pulipaka-56417a2',
#          'display_url': 'linkedin.com/in/dr-ganapath…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 71083,
#      'friends_count': 28614,
#      'listed_count': 3327,
#      'created_at': 'Tue Nov 17 02:19:09 +0000 2015',
#      'favourites_count': 9,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 50792,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/998301258413850625/9BZwTjgv_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/998301258413850625/9BZwTjgv_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4263007693/1566318502',
#      'profile_link_color': 'DD2E44',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
# ...
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 8169,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1192563966729437184/3q2vGNoO_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1192563966729437184/3q2vGNoO_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1140007642800283648/1571866913',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Nov 21 09:07:40 +0000 2019',
#    'id': 1197441435240423424,
#    'id_str': '1197441435240423424',
#    'text': 'RT @martinfleis: Let me introduce you to my new python package - momepy: Urban Morphology Measuring Toolkit. Building on @geopandas, @pysal…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'martinfleis',
#       'name': 'Martin Fleischmann',
#       'id': 883391969447206913,
#       'id_str': '883391969447206913',
#       'indices': [3, 15]},
#      {'screen_name': 'geopandas',
#       'name': 'GeoPandas',
#       'id': 2790503132,
#       'id_str': '2790503132',
#       'indices': [121, 131]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1082700543489916929,
#     'id_str': '1082700543489916929',
#     'name': 'Chimango Chisuwo',
#     'screen_name': 'ChisuwoChimango',
#     'location': '',
#     'description': '42',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 32,
#     'friends_count': 60,
#     'listed_count': 2,
#     'created_at': 'Tue Jan 08 18:08:19 +0000 2019',
#     'favourites_count': 517,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 46,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1183297533713539072/2DRCodm__normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1183297533713539072/2DRCodm__normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1082700543489916929/1567836408',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Nov 20 22:29:33 +0000 2019',
#     'id': 1197280847780614150,
#     'id_str': '1197280847780614150',
#     'text': 'Let me introduce you to my new python package - momepy: Urban Morphology Measuring Toolkit. Building on @geopandas,… https://t.co/TJwYupZ5dh',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'geopandas',
#        'name': 'GeoPandas',
#        'id': 2790503132,
#        'id_str': '2790503132',
#        'indices': [104, 114]}],
#      'urls': [{'url': 'https://t.co/TJwYupZ5dh',
#        'expanded_url': 'https://twitter.com/i/web/status/1197280847780614150',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 883391969447206913,
#      'id_str': '883391969447206913',
#      'name': 'Martin Fleischmann',
#      'screen_name': 'martinfleis',
#      'location': 'Glasgow, Scotland',
#      'description': 'Researcher in urban morphology & geographic data science. University of Strathclyde, Glasgow. In Czech as @ctvrtkar.',
#      'url': 'https://t.co/wXhf3H7tEE',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/wXhf3H7tEE',
#          'expanded_url': 'http://martinfleischmann.net',
#          'display_url': 'martinfleischmann.net',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 88,
#      'friends_count': 105,
#      'listed_count': 1,
#      'created_at': 'Fri Jul 07 18:27:12 +0000 2017',
#      'favourites_count': 187,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 131,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/883775382763294721/u0kyrxBg_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/883775382763294721/u0kyrxBg_normal.jpg',
#      'profile_link_color': 'ABB8C2',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': True,
#     'quoted_status_id': 1197216711256223744,
#     'quoted_status_id_str': '1197216711256223744',
#     'quoted_status': {'created_at': 'Wed Nov 20 18:14:41 +0000 2019',
#      'id': 1197216711256223744,
#      'id_str': '1197216711256223744',
#      'text': "Just published in #JOSS_theOJ: 'momepy: Urban Morphology Measuring Toolkit' https://t.co/Ufm2gHFce5",
#      'truncated': False,
#      'entities': {'hashtags': [{'text': 'JOSS_theOJ', 'indices': [18, 29]}],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [{'url': 'https://t.co/Ufm2gHFce5',
#         'expanded_url': 'https://joss.theoj.org/papers/10.21105/joss.01807',
#         'display_url': 'joss.theoj.org/papers/10.2110…',
#         'indices': [76, 99]}]},
#      'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#      'source': '<a href="https://joss.theoj.org" rel="nofollow">Whedon/JOSS</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'user': {'id': 723667033532018689,
#       'id_str': '723667033532018689',
#       'name': 'JOSS',
#       'screen_name': 'JOSS_TheOJ',
#       'location': '',
#       'description': 'The Journal of Open Source Software. The developer friendly software journal. Tweets by: @KMMoerman and Whedon',
#       'url': 'https://t.co/tZnku3QAlM',
#       'entities': {'url': {'urls': [{'url': 'https://t.co/tZnku3QAlM',
#           'expanded_url': 'http://joss.theoj.org/',
#           'display_url': 'joss.theoj.org',
#           'indices': [0, 23]}]},
#        'description': {'urls': []}},
#       'protected': False,
#       'followers_count': 2999,
#       'friends_count': 79,
#       'listed_count': 68,
#       'created_at': 'Sat Apr 23 00:17:20 +0000 2016',
#       'favourites_count': 354,
#       'utc_offset': None,
#       'time_zone': None,
#       'geo_enabled': False,
#       'verified': False,
#       'statuses_count': 432,
#       'lang': None,
#       'contributors_enabled': False,
#       'is_translator': False,
#       'is_translation_enabled': False,
#       'profile_background_color': 'F5F8FA',
#       'profile_background_image_url': None,
#       'profile_background_image_url_https': None,
#       'profile_background_tile': False,
#       'profile_image_url': 'http://pbs.twimg.com/profile_images/723960899120316416/YVpibxGx_normal.jpg',
#       'profile_image_url_https': 'https://pbs.twimg.com/profile_images/723960899120316416/YVpibxGx_normal.jpg',
#       'profile_banner_url': 'https://pbs.twimg.com/profile_banners/723667033532018689/1461440646',
#       'profile_link_color': '1DA1F2',
#       'profile_sidebar_border_color': 'C0DEED',
#       'profile_sidebar_fill_color': 'DDEEF6',
#       'profile_text_color': '333333',
#       'profile_use_background_image': True,
#       'has_extended_profile': False,
#       'default_profile': True,
#       'default_profile_image': False,
#       'following': False,
#       'follow_request_sent': False,
#       'notifications': False,
#       'translator_type': 'none'},
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 2,
#      'favorite_count': 4,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'retweet_count': 13,
#     'favorite_count': 29,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': True,
#    'quoted_status_id': 1197216711256223744,
#    'quoted_status_id_str': '1197216711256223744',
#    'retweet_count': 13,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Nov 21 09:07:02 +0000 2019',
#    'id': 1197441276498644993,
#    'id_str': '1197441276498644993',
#    'text': '7 Reasons Why #Python is Perfect for #Startups\xa0https://t.co/V9lYtC1pfu https://t.co/ADy5Tf8uTr',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Python', 'indices': [14, 21]},
#      {'text': 'Startups', 'indices': [37, 46]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/V9lYtC1pfu',
#       'expanded_url': 'https://buff.ly/2QgmAI5',
#       'display_url': 'buff.ly/2QgmAI5',
#       'indices': [47, 70]}],
#     'media': [{'id': 1197441272262352896,
#       'id_str': '1197441272262352896',
#       'indices': [71, 94],
#       'media_url': 'http://pbs.twimg.com/media/EJ4qfiiW4AA8as3.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/EJ4qfiiW4AA8as3.jpg',
#       'url': 'https://t.co/ADy5Tf8uTr',
#       'display_url': 'pic.twitter.com/ADy5Tf8uTr',
#       'expanded_url': 'https://twitter.com/markITwrite/status/1197441276498644993/photo/1',
#       'type': 'photo',
#       'sizes': {'small': {'w': 680, 'h': 264, 'resize': 'fit'},
#        'large': {'w': 1440, 'h': 560, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1200, 'h': 467, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1197441272262352896,
#       'id_str': '1197441272262352896',
#       'indices': [71, 94],
#       'media_url': 'http://pbs.twimg.com/media/EJ4qfiiW4AA8as3.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/EJ4qfiiW4AA8as3.jpg',
#       'url': 'https://t.co/ADy5Tf8uTr',
#       'display_url': 'pic.twitter.com/ADy5Tf8uTr',
#       'expanded_url': 'https://twitter.com/markITwrite/status/1197441276498644993/photo/1',
#       'type': 'photo',
#       'sizes': {'small': {'w': 680, 'h': 264, 'resize': 'fit'},
#        'large': {'w': 1440, 'h': 560, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1200, 'h': 467, 'resize': 'fit'}}}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 479758700,
#     'id_str': '479758700',
#     'name': 'markITwrite',
#     'screen_name': 'markITwrite',
#     'location': 'UK & Ireland',
#     'description': 'Superior quality Technology and Business content at affordable prices. Our words - your message.',
#     'url': 'https://t.co/f5fEtcEB7T',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/f5fEtcEB7T',
#         'expanded_url': 'https://markitwrite.com/',
#         'display_url': 'markitwrite.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 136393,
#     'friends_count': 131736,
#     'listed_count': 3037,
#     'created_at': 'Tue Jan 31 18:49:03 +0000 2012',
#     'favourites_count': 5398,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 86344,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'FA743E',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/913342127203078145/ShQm6oRM_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/913342127203078145/ShQm6oRM_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/479758700/1506592635',
#     'profile_link_color': '1B95E0',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'}],
#  'search_metadata': {'completed_in': 0.082,
#   'max_id': 1197441736789970945,
#   'max_id_str': '1197441736789970945',
#   'next_results': '?max_id=1197441276498644992&q=python&lang=en&include_entities=1&result_type=recent',
#   'query': 'python',
#   'refresh_url': '?since_id=1197441736789970945&q=python&lang=en&result_type=recent&include_entities=1',
#   'count': 15,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %%
class MyStreamer(TwythonStreamer):
    def on_success(self, data):
        if 'text' in data:
            print(data['text'])

    def on_error(self, status_code, data):
        print(status_code)

        # Want to stop trying to get data because of the error?
        # Uncomment the next line!
        # self.disconnect()

# %%
stream = MyStreamer(CONSUMER_KEY, CONSUMER_SECRET,
                  ACCESS_TOKEN, ACCESS_SECRET)

#Filtering public statuses
stream.statuses.filter(track='san diego')
