# %%
# Import the modules
import os
import time
import datetime as DT
import tweepy
import json
import pandas as pd
import numpy as np
from opencage.geocoder import OpenCageGeocode
import functools
def conjunction(*conditions):
    return functools.reduce(np.logical_and, conditions)
def DT_from_utc_to_local(utc_datetime):
    now_timestamp = time.time()
    offset = DT.datetime.fromtimestamp(now_timestamp) - DT.datetime.utcfromtimestamp(now_timestamp)
    return utc_datetime + offset

# Load credentials from json file:
os.chdir(r"C:\Users\angy4\BootCamp-HW\d3-data-viz") #Folder Location
with open("twitter_credentials.json", "r") as file:
    creds = json.load(file)

# %%
#Set up Twitter Authentication
auth = tweepy.OAuthHandler(creds['CONSUMER_KEY'], creds['CONSUMER_SECRET'])
auth.set_access_token(creds['ACCESS_TOKEN'], creds['ACCESS_SECRET'])
api = tweepy.API(auth)

# %%
#Begin API Scrape - Day 1
listTweets1 = []

today = DT.date.today()
StartDt = today - DT.timedelta(days=7)
EndDt = DT.date.today() - DT.timedelta(days=6)
searchterm = '#feelthebern'
keyword = searchterm+' since:'+str(StartDt)+' until:'+str(EndDt)+' -filter:retweets'
NumTweets = 200

def get_tweets1(listTweets1, keyword, NumTweets):
    # Iterate through all tweets containing the given word, api search mode
    for tweet in tweepy.Cursor(api.search, q=keyword).items(NumTweets):
        # Add tweets in this format
        dict_ = {'Screen_Name': tweet.user.screen_name,
                'User_Name': tweet.user.name,
                'Tweet_Created_At': str(DT_from_utc_to_local(tweet.created_at)),
                'Tweet_Text': tweet.text,
                'Hashtags': tweet.entities.get('hashtags'), #How? - get only hashtag text
                'User_Location': str(tweet.user.location),
                'Tweet_Coordinates': str(tweet.coordinates),
                'Tweet_Place': str(tweet.place),
                'Retweet_Count': str(tweet.retweet_count),
                'Retweeted': str(tweet.retweeted),
                'Favorite_Count': str(tweet.favorite_count),
                'Favorited': str(tweet.favorited),
                'Replied': str(tweet.in_reply_to_status_id_str),
                'Tweet_URL': tweet.entities.get('urls') #How? - get only expanded url?
                }
        listTweets1.append(dict_)   
    return listTweets1

get_tweets1(listTweets1, keyword, NumTweets)
# Out:
# ---------------------------------------------------------------------------
# TweepError                                Traceback (most recent call last)
# <ipython-input-8-68d625222d05> in <module>
#      31     return listTweets1
#      32
# ---> 33 get_tweets1(listTweets1, keyword, NumTweets)
#
# <ipython-input-8-68d625222d05> in get_tweets1(listTweets1, keyword, NumTweets)
#      11 def get_tweets1(listTweets1, keyword, NumTweets):
#      12     # Iterate through all tweets containing the given word, api search mode
# ---> 13     for tweet in tweepy.Cursor(api.search, q=keyword).items(NumTweets):
#      14         # Add tweets in this format
#      15         dict_ = {'Screen_Name': tweet.user.screen_name,
#
# ~\Anaconda3\lib\site-packages\tweepy\cursor.py in __next__(self)
#      45
#      46     def __next__(self):
# ---> 47         return self.next()
#      48
#      49     def next(self):
#
# ~\Anaconda3\lib\site-packages\tweepy\cursor.py in next(self)
#     193         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     194             # Reached end of current page, get the next page...
# --> 195             self.current_page = self.page_iterator.next()
#     196             self.page_index = -1
#     197         self.page_index += 1
#
# ~\Anaconda3\lib\site-packages\tweepy\cursor.py in next(self)
#     104
#     105         if self.index >= len(self.results) - 1:
# --> 106             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kargs)
#     107
#     108             if hasattr(self.method, '__self__'):
#
# ~\Anaconda3\lib\site-packages\tweepy\binder.py in _call(*args, **kwargs)
#     248                 return method
#     249             else:
# --> 250                 return method.execute()
#     251         finally:
#     252             method.session.close()
#
# ~\Anaconda3\lib\site-packages\tweepy\binder.py in execute(self)
#     231                     raise RateLimitError(error_msg, resp)
#     232                 else:
# --> 233                     raise TweepError(error_msg, resp, api_code=api_error_code)
#     234
#     235             # Parse the response payload
#
# TweepError: Twitter error response: status code = 429

# %%
df1 = pd.DataFrame.from_dict(listTweets1, orient='columns')
df1
# Out:
#     Favorite_Count Favorited  \
# 0                0     False
# 1                9     False
# 2                4     False
# 3                2     False
# 4                0     False
# 5                0     False
# 6                0     False
# 7                0     False
# 8                0     False
# 9                2     False
# 10               5     False
# 11               1     False
# 12               0     False
# 13               0     False
# 14               1     False
# 15               0     False
# 16               0     False
# 17               0     False
# 18               2     False
# 19               2     False
# 20               0     False
# 21               3     False
# 22               0     False
# 23               0     False
# 24              24     False
# 25               0     False
# 26               1     False
# 27               2     False
# 28               1     False
# 29              16     False
# ..             ...       ...
# 170              0     False
# 171              0     False
# 172              0     False
# 173              0     False
# 174              0     False
# 175              0     False
# 176              0     False
# 177              0     False
# 178              0     False
# 179              0     False
# 180              0     False
# 181              1     False
# 182              1     False
# 183              0     False
# 184              0     False
# 185              1     False
# 186              0     False
# 187              0     False
# 188              0     False
# 189              0     False
# 190              0     False
# 191              0     False
# 192              0     False
# 193              0     False
# 194              7     False
# 195              0     False
# 196              0     False
# 197              0     False
# 198              7     False
# 199              1     False
#
#                                               Hashtags              Replied  \
# 0                                                   []                 None
# 1         [{'text': 'FortWorth', 'indices': [48, 58]}]                 None
# 2    [{'text': 'Bernie2020', 'indices': [43, 54]}, ...                 None
# 3             [{'text': 'Trump', 'indices': [41, 47]}]  1198726363454361601
# 4    [{'text': 'feelthebern', 'indices': [74, 86]},...                 None
# 5    [{'text': 'NotMeUs', 'indices': [0, 8]}, {'tex...                 None
# 6    [{'text': 'BernieSanders2020', 'indices': [47,...                 None
# 7       [{'text': 'blackballed', 'indices': [48, 60]}]                 None
# 8    [{'text': 'BernieSanders', 'indices': [25, 39]...                 None
# 9    [{'text': 'Thanksgiving', 'indices': [0, 13]},...                 None
# 10   [{'text': 'CancelStudentDebt', 'indices': [19,...                 None
# 11      [{'text': 'FeelTheBern', 'indices': [19, 31]}]                 None
# 12   [{'text': 'FuckMSNBC', 'indices': [0, 10]}, {'...                 None
# 13                                                  []                 None
# 14   [{'text': 'FeelTheBern', 'indices': [0, 12]}, ...                 None
# 15   [{'text': 'buttigieg', 'indices': [0, 10]}, {'...                 None
# 16                                                  []                 None
# 17             [{'text': 'STFU', 'indices': [44, 49]}]  1197889908536426502
# 18   [{'text': 'NotMeUs', 'indices': [31, 39]}, {'t...                 None
# 19   [{'text': 'InThisTogether', 'indices': [0, 15]...                 None
# 20   [{'text': 'PresidentSanders', 'indices': [33, ...                 None
# 21   [{'text': 'BernieInNH', 'indices': [0, 11]}, {...                 None
# 22                                                  []                 None
# 23      [{'text': 'FeelTheBern', 'indices': [15, 27]}]                 None
# 24                                                  []                 None
# 25      [{'text': 'FeelTheBern', 'indices': [71, 83]}]                 None
# 26      [{'text': 'FeelTheBern', 'indices': [84, 96]}]  1198664728723234822
# 27       [{'text': 'BernieInNH', 'indices': [72, 83]}]                 None
# 28      [{'text': 'FeelTheBern', 'indices': [29, 41]}]                 None
# 29   [{'text': 'Hindsight2020', 'indices': [39, 53]...  1198727973257367553
# ..                                                 ...                  ...
# 170  [{'text': 'Election2020', 'indices': [0, 13]},...                 None
# 171                                                 []  1198616429588705280
# 172                                                 []  1198614097291403267
# 173     [{'text': 'FeelTheBern', 'indices': [21, 33]}]                 None
# 174  [{'text': 'FeelTheBern', 'indices': [0, 12]}, ...                 None
# 175  [{'text': 'FeelTheBern', 'indices': [0, 12]}, ...                 None
# 176  [{'text': 'FeelTheBern', 'indices': [0, 12]}, ...                 None
# 177  [{'text': 'FeelTheBern', 'indices': [0, 12]}, ...                 None
# 178                                                 []  1198596957889007617
# 179                                                 []                 None
# 180  [{'text': 'FeelTheBern', 'indices': [0, 12]}, ...                 None
# 181  [{'text': 'Trump', 'indices': [10, 16]}, {'tex...                 None
# 182  [{'text': 'FeelTheBern', 'indices': [0, 12]}, ...                 None
# 183  [{'text': 'bernie2020', 'indices': [57, 68]}, ...                 None
# 184   [{'text': 'TurnUpTheBern', 'indices': [78, 92]}]                 None
# 185           [{'text': 'm4all', 'indices': [19, 25]}]                 None
# 186     [{'text': 'feelthebern', 'indices': [43, 55]}]                 None
# 187  [{'text': 'freedomwave', 'indices': [11, 23]},...  1198452087119593474
# 188  [{'text': 'Union', 'indices': [0, 6]}, {'text'...                 None
# 189  [{'text': 'FeelTheBern', 'indices': [0, 12]}, ...                 None
# 190  [{'text': 'FeelTheBern', 'indices': [0, 12]}, ...                 None
# 191  [{'text': 'FeelTheBern', 'indices': [0, 12]}, ...                 None
# 192  [{'text': 'FeelTheBern', 'indices': [0, 12]}, ...                 None
# 193  [{'text': 'FeelTheBern', 'indices': [0, 12]}, ...                 None
# 194  [{'text': 'FeelTheBern', 'indices': [0, 12]}, ...                 None
# 195  [{'text': 'FeelTheBern', 'indices': [0, 12]}, ...                 None
# 196  [{'text': 'FeelTheBern', 'indices': [0, 12]}, ...                 None
# 197  [{'text': 'FeelTheBern', 'indices': [0, 12]}, ...                 None
# 198  [{'text': 'NHpolitics', 'indices': [85, 96]}, ...                 None
# 199  [{'text': 'ihadthetimeofmylife', 'indices': [8...                 None
#
#     Retweet_Count Retweeted      Screen_Name  \
# 0               0     False   AaronsConcepts
# 1               7     False   kpalomares2028
# 2               5     False       rickdumais
# 3               0     False         RepPress
# 4               0     False       rickdumais
# 5               0     False    PorkchopNorth
# 6               0     False       Getout0000
# 7               0     False        xreal_vfx
# 8               0     False        va_maga12
# 9               2     False     milanos_best
# 10              5     False       doranhelix
# 11              0     False    brittondperry
# 12              0     False   AdvocateRaptor
# 13              0     False        Gaytheist
# 14              0     False            e3ltd
# 15              0     False   Humanbeing1973
# 16              0     False        Evan_Dood
# 17              0     False         Wiskyeye
# 18              0     False     PopulistLeft
# 19              1     False  NEWomen4Justice
# 20              0     False       Jessperado
# 21              1     False  TheresaSchroe14
# 22              0     False   BratislavaLive
# 23              0     False     ThatMikeCruz
# 24             11     False    normansolomon
# 25              0     False        spoookymb
# 26              0     False         houser43
# 27              0     False  TheresaSchroe14
# 28              0     False        borgardal
# 29              4     False          WilesWj
# ..            ...       ...              ...
# 170             0     False    matthewgsteel
# 171             0     False    YoshiMukudaiS
# 172             0     False    YoshiMukudaiS
# 173             0     False      Lwazi_Somya
# 174             1     False   Belgiumfbernie
# 175             1     False   Belgiumfbernie
# 176             0     False   Belgiumfbernie
# 177             0     False   Belgiumfbernie
# 178             0     False    YoshiMukudaiS
# 179             0     False       cmarra1020
# 180             0     False   Belgiumfbernie
# 181             3     False     10WallStreet
# 182             0     False   Belgiumfbernie
# 183             0     False        lharman73
# 184             0     False         DJFlorek
# 185             1     False      mass_writer
# 186             0     False  love_n_peaceboy
# 187             0     False  Evangel_Charles
# 188             0     False   MimiTexasAngel
# 189             0     False   Belgiumfbernie
# 190             0     False   Belgiumfbernie
# 191             0     False   Belgiumfbernie
# 192             0     False   Belgiumfbernie
# 193             0     False   Belgiumfbernie
# 194             7     False   Belgiumfbernie
# 195             0     False   Belgiumfbernie
# 196             0     False   Belgiumfbernie
# 197             0     False   Belgiumfbernie
# 198             2     False        novenator
# 199             1     False     The_lez_bear
#
#                                      Tweet_Coordinates     Tweet_Created_At  \
# 0                                                 None  2019-11-24 15:59:07
# 1                                                 None  2019-11-24 15:58:26
# 2                                                 None  2019-11-24 15:55:30
# 3                                                 None  2019-11-24 15:54:52
# 4    {'type': 'Point', 'coordinates': [-71.94070099...  2019-11-24 15:45:50
# 5                                                 None  2019-11-24 15:45:02
# 6                                                 None  2019-11-24 15:39:10
# 7                                                 None  2019-11-24 15:34:34
# 8                                                 None  2019-11-24 15:32:57
# 9                                                 None  2019-11-24 15:32:30
# 10                                                None  2019-11-24 15:25:59
# 11                                                None  2019-11-24 15:25:42
# 12                                                None  2019-11-24 15:25:11
# 13                                                None  2019-11-24 15:24:58
# 14                                                None  2019-11-24 15:22:36
# 15                                                None  2019-11-24 15:20:01
# 16                                                None  2019-11-24 15:17:18
# 17                                                None  2019-11-24 15:12:01
# 18                                                None  2019-11-24 15:10:01
# 19                                                None  2019-11-24 14:55:02
# 20                                                None  2019-11-24 14:50:51
# 21                                                None  2019-11-24 14:48:52
# 22                                                None  2019-11-24 14:46:38
# 23                                                None  2019-11-24 14:41:37
# 24                                                None  2019-11-24 14:40:04
# 25                                                None  2019-11-24 14:39:08
# 26                                                None  2019-11-24 14:38:29
# 27                                                None  2019-11-24 14:37:12
# 28                                                None  2019-11-24 14:35:26
# 29                                                None  2019-11-24 14:33:50
# ..                                                 ...                  ...
# 170                                               None  2019-11-24 06:59:22
# 171                                               None  2019-11-24 06:58:44
# 172                                               None  2019-11-24 06:56:40
# 173                                               None  2019-11-24 06:56:08
# 174                                               None  2019-11-24 06:54:11
# 175                                               None  2019-11-24 06:53:53
# 176                                               None  2019-11-24 06:49:37
# 177                                               None  2019-11-24 06:49:07
# 178                                               None  2019-11-24 06:47:24
# 179                                               None  2019-11-24 06:47:15
# 180                                               None  2019-11-24 06:44:44
# 181                                               None  2019-11-24 06:44:03
# 182                                               None  2019-11-24 06:40:11
# 183                                               None  2019-11-24 06:38:16
# 184                                               None  2019-11-24 06:36:39
# 185                                               None  2019-11-24 06:35:34
# 186                                               None  2019-11-24 06:21:41
# 187                                               None  2019-11-24 06:15:55
# 188                                               None  2019-11-24 06:13:28
# 189                                               None  2019-11-24 06:12:56
# 190                                               None  2019-11-24 06:12:48
# 191                                               None  2019-11-24 06:11:43
# 192                                               None  2019-11-24 06:10:49
# 193                                               None  2019-11-24 06:10:10
# 194                                               None  2019-11-24 06:08:12
# 195                                               None  2019-11-24 06:07:56
# 196                                               None  2019-11-24 06:07:42
# 197                                               None  2019-11-24 06:07:20
# 198                                               None  2019-11-24 06:05:59
# 199                                               None  2019-11-24 06:04:56
#
#                                            Tweet_Place  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4    Place(_api=<tweepy.api.API object at 0x0000022...
# 5                                                 None
# 6                                                 None
# 7                                                 None
# 8                                                 None
# 9                                                 None
# 10                                                None
# 11                                                None
# 12                                                None
# 13                                                None
# 14                                                None
# 15                                                None
# 16                                                None
# 17                                                None
# 18                                                None
# 19                                                None
# 20                                                None
# 21                                                None
# 22                                                None
# 23                                                None
# 24                                                None
# 25                                                None
# 26                                                None
# 27                                                None
# 28                                                None
# 29                                                None
# ..                                                 ...
# 170                                               None
# 171                                               None
# 172                                               None
# 173                                               None
# 174                                               None
# 175                                               None
# 176                                               None
# 177                                               None
# 178                                               None
# 179                                               None
# 180                                               None
# 181                                               None
# 182                                               None
# 183                                               None
# 184                                               None
# 185                                               None
# 186                                               None
# 187                                               None
# 188                                               None
# 189                                               None
# 190                                               None
# 191                                               None
# 192                                               None
# 193                                               None
# 194                                               None
# 195                                               None
# 196                                               None
# 197                                               None
# 198                                               None
# 199  Place(_api=<tweepy.api.API object at 0x0000022...
#
#                                             Tweet_Text  \
# 0    👇🏿👇🏿👇🏿👇🏿👇🏿👇🏿👇🏿👇🏿👇🏿👇🏿👇🏿\n👉🏿👇🏾👇🏾👇🏾👇🏾👇🏾👇🏾👇🏾👇🏾👇🏾👈🏿...
# 1    Another successful Saturday of block walking i...
# 2    New @BernieSanders door hangers are 🔥🔥🔥✊✊✊ #Be...
# 3    @michaelsayman Only @BernieSanders beats #Trum...
# 4    Justin Long with the surprise speach at today'...
# 5    #NotMeUs #FeelTheBern\n@SenSanders https://t.c...
# 6    Get the new “class warfare” w/ any donation to...
# 7    @blitzchungHS I stood up for myself &amp; I wa...
# 8    https://t.co/3cfqM5H7sh  #BernieSanders #FeelT...
# 9    #Thanksgiving is prime time to canvass your fa...
# 10   This. Is. Not. OK. #CancelStudentDebt #BernieS...
# 11   Bless you, Bernie. #FeelTheBern https://t.co/V...
# 12   #FuckMSNBC because both Bernie and Yang deserv...
# 13   Or how about you communicate with your corpora...
# 14   #FeelTheBern #Bernie2020 #WarrenForVP #Pressle...
# 15   #buttigieg #buttigieg2020 #cnn #msnbc #feelthe...
# 16   The 3 richest Americans have more wealth than ...
# 17   @HillaryClinton No disrespect intended but, #S...
# 18   Worker Appreciation Tour Rally\n#NotMeUs #Feel...
# 19   #InThisTogether #UsNotMe #Bernie2020 #FeelTheB...
# 20   Healthy enough to be President!! #PresidentSan...
# 21   #BernieInNH #FeelTheBern 🔥 #NotMeUs https://t....
# 22   Some of the best coverage of Bernie Sanders I ...
# 23   @BernieSanders #FeelTheBern? https://t.co/Fr87...
# 24   Quit saying that Bernie Sanders can't win — he...
# 25   Bernie Sanders is a dancing queen and no one c...
# 26   @MikeBloomberg Just a friendly reminder that I...
# 27   "Our average contribution as off tonight is $1...
# 28   How can you not like Bernie?\n#FeelTheBern htt...
# 29   @BernieSanders Bernie. Beats. tRump. \n\n#Hind...
# ..                                                 ...
# 170  #Election2020 Democratic Debate - SNL https://...
# 171  @SaraN12533752 @XRebellionUK This includes not...
# 172  @SaraN12533752 @XRebellionUK (cont.) in which ...
# 173  You are beginning to #FeelTheBern https://t.co...
# 174  #FeelTheBern #BernieSanders #BernieBeatsTrump ...
# 175  #FeelTheBern #BernieSanders #BernieBeatsTrump ...
# 176  #FeelTheBern #BernieSanders #BernieBeatsTrump ...
# 177  #FeelTheBern #BernieSanders #BernieBeatsTrump ...
# 178  @SaraN12533752 @XRebellionUK Stop political ho...
# 179  How many piece of shot panelists can @ThisWeek...
# 180  #FeelTheBern #BernieSanders #BernieBeatsTrump ...
# 181  Curiously #Trump Adopted Many of #Bernie's Pol...
# 182  #FeelTheBern #BernieSanders #BernieBeatsTrump ...
# 183  Sanders rallies that you will never see in CNN...
# 184  Seven Nation Army - Bernie Sanders for Preside...
# 185  Warren talks about #m4all, but she really does...
# 186  dood. an old man doesn't see the obvious.. #fe...
# 187  @shaunking #freedomwave #FeelTheBern #BernieBe...
# 188  #Union #1U\n#Solidarity \n#Workers \n#WeThePeo...
# 189  #FeelTheBern #BernieSanders #BernieBeatsTrump ...
# 190  #FeelTheBern #BernieSanders #BernieBeatsTrump ...
# 191  #FeelTheBern #BernieSanders #BernieBeatsTrump ...
# 192  #FeelTheBern #BernieSanders #BernieBeatsTrump ...
# 193  #FeelTheBern #BernieSanders #BernieBeatsTrump ...
# 194  #FeelTheBern #BernieSanders #BernieBeatsTrump ...
# 195  #FeelTheBern #BernieSanders #BernieBeatsTrump ...
# 196  #FeelTheBern #BernieSanders #BernieBeatsTrump ...
# 197  #FeelTheBern #BernieSanders #BernieBeatsTrump ...
# 198  Bernie's a hit as he dances on the stump in Ne...
# 199  I’m sorry but my candidate is way cuter than y...
#
#                                              Tweet_URL  \
# 0    [{'url': 'https://t.co/yjeJ8AXLdU', 'expanded_...
# 1    [{'url': 'https://t.co/J7jtPuLIEb', 'expanded_...
# 2                                                   []
# 3    [{'url': 'https://t.co/fVBSG6WbTI', 'expanded_...
# 4    [{'url': 'https://t.co/O7o0rzLX6S', 'expanded_...
# 5    [{'url': 'https://t.co/vKmM8rruw1', 'expanded_...
# 6    [{'url': 'https://t.co/ww407hOLi2', 'expanded_...
# 7    [{'url': 'https://t.co/9wht78SQjS', 'expanded_...
# 8    [{'url': 'https://t.co/3cfqM5H7sh', 'expanded_...
# 9    [{'url': 'https://t.co/Hwa1vrrUY0', 'expanded_...
# 10   [{'url': 'https://t.co/VcVSfscGTK', 'expanded_...
# 11   [{'url': 'https://t.co/VTH7w0xhA3', 'expanded_...
# 12                                                  []
# 13   [{'url': 'https://t.co/xNwwp4rGrN', 'expanded_...
# 14   [{'url': 'https://t.co/lwpWzoyBS3', 'expanded_...
# 15   [{'url': 'https://t.co/nBlqQKeINs', 'expanded_...
# 16   [{'url': 'https://t.co/CVFbzcNqKv', 'expanded_...
# 17   [{'url': 'https://t.co/Q99OPtKS1b', 'expanded_...
# 18   [{'url': 'https://t.co/JxHTI3ZO1S', 'expanded_...
# 19   [{'url': 'https://t.co/O9SisWjJ9w', 'expanded_...
# 20   [{'url': 'https://t.co/VfKnpF4Ue2', 'expanded_...
# 21   [{'url': 'https://t.co/VTl2l7Wi0A', 'expanded_...
# 22   [{'url': 'https://t.co/YQ7swUdx8P', 'expanded_...
# 23                                                  []
# 24   [{'url': 'https://t.co/W9nwQy31OZ', 'expanded_...
# 25   [{'url': 'https://t.co/qkhTZLnvDA', 'expanded_...
# 26                                                  []
# 27   [{'url': 'https://t.co/GFEXGIVDuI', 'expanded_...
# 28   [{'url': 'https://t.co/tVqxgzNp6E', 'expanded_...
# 29                                                  []
# ..                                                 ...
# 170  [{'url': 'https://t.co/bhEBKy6otW', 'expanded_...
# 171  [{'url': 'https://t.co/4Xwyaxmipm', 'expanded_...
# 172  [{'url': 'https://t.co/Bo4MiSLOWz', 'expanded_...
# 173  [{'url': 'https://t.co/cn5SOFoVtO', 'expanded_...
# 174  [{'url': 'https://t.co/13eDPKyl3R', 'expanded_...
# 175  [{'url': 'https://t.co/aOCoR5qMy9', 'expanded_...
# 176  [{'url': 'https://t.co/pEKhyPPWlv', 'expanded_...
# 177  [{'url': 'https://t.co/panqJyUl9I', 'expanded_...
# 178  [{'url': 'https://t.co/wzzRozgrxX', 'expanded_...
# 179  [{'url': 'https://t.co/0gPK6ztPl3', 'expanded_...
# 180  [{'url': 'https://t.co/JHFtIR00JX', 'expanded_...
# 181  [{'url': 'https://t.co/trehIgkenQ', 'expanded_...
# 182  [{'url': 'https://t.co/GRi14IL6sz', 'expanded_...
# 183  [{'url': 'https://t.co/7bOEPcf8S7', 'expanded_...
# 184  [{'url': 'https://t.co/kKDYW1bx8v', 'expanded_...
# 185  [{'url': 'https://t.co/ncQUuDtnsr', 'expanded_...
# 186                                                 []
# 187                                                 []
# 188  [{'url': 'https://t.co/bAVIDw0uR1', 'expanded_...
# 189  [{'url': 'https://t.co/VliN7Sirkw', 'expanded_...
# 190  [{'url': 'https://t.co/uuUawk9wh4', 'expanded_...
# 191  [{'url': 'https://t.co/lfWKZHIQk2', 'expanded_...
# 192  [{'url': 'https://t.co/K0w6pBBhYx', 'expanded_...
# 193  [{'url': 'https://t.co/1BlnUqbhTw', 'expanded_...
# 194  [{'url': 'https://t.co/dpJzABIXrj', 'expanded_...
# 195  [{'url': 'https://t.co/844D6b2pRP', 'expanded_...
# 196  [{'url': 'https://t.co/6d6u25vPYR', 'expanded_...
# 197  [{'url': 'https://t.co/tVDwugZlnu', 'expanded_...
# 198  [{'url': 'https://t.co/jkZW9LMQzq', 'expanded_...
# 199  [{'url': 'https://t.co/LH2VfdvNoL', 'expanded_...
#
#                       User_Location  \
# 0         United States of America
# 1                        Texas, USA
# 2                New Hampshire, USA
# 3
# 4                New Hampshire, USA
# 5             Everywhere & Nowhere
# 6                   Baton Rouge, LA
# 7
# 8                  RIGHT here in VA
# 9                        Maine, USA
# 10                    Lancaster, PA
# 11
# 12
# 13                       Austin, TX
# 14                         NY State
# 15
# 16                    Nashville, TN
# 17                          Alabama
# 18                 Grand Rapids, MI
# 19                    NorthEast USA
# 20                          Florida
# 21                 SouthEastern USA
# 22             Bratislava, Slovakia
# 23                  Tucson, Arizona
# 24              Northern California
# 25
# 26
# 27                 SouthEastern USA
# 28                 Aalborg, Denmark
# 29             Northern California
# ..                              ...
# 170                       #Westbank
# 171                           Osaka
# 172                           Osaka
# 173  Nelson Mandela Bay - Cape Town
# 174                         Belgium
# 175                         Belgium
# 176                         Belgium
# 177                         Belgium
# 178                           Osaka
# 179
# 180                         Belgium
# 181            Citizen of The World
# 182                         Belgium
# 183                   Wimberley, TX
# 184               Lehigh Valley Pa.
# 185              Massachusetts, USA
# 186             Love, United States
# 187
# 188                    Planet Earth
# 189                         Belgium
# 190                         Belgium
# 191                         Belgium
# 192                         Belgium
# 193                         Belgium
# 194                         Belgium
# 195                         Belgium
# 196                         Belgium
# 197                         Belgium
# 198                     Nevada, USA
# 199                Philadelphia, PA
#
#                                           User_Name
# 0                            Texans For Bernie 2020
# 1                                   Karla Palomares
# 2                        Rick For Bernie🌹✊🏻✊🏼✊🏽✊🏾✊🏿
# 3                              Representative Press
# 4                        Rick For Bernie🌹✊🏻✊🏼✊🏽✊🏾✊🏿
# 5                                          Porkchop
# 6                                        getout0000
# 7                                        The Ras D!
# 8                                            VAMAGA
# 9                              Milan Satcher MD MPH
# 10                   Michael, Not a Real Democrat🗒🌹
# 11                                Jörg Herman Bauer
# 12                              🧢🧢Raptor Advocate🧢🧢
# 13                                        Gaytheist
# 14                                  David J. Baxley
# 15                                       Humanbeing
# 16                                        Evan King
# 17                                  Michael Ratliff
# 18                                    Populist Left
# 19                                NEWomenforJustice
# 20                                    Jessica Jones
# 21                                  Calibernication
# 22                                William Peynsaert
# 23                                     Michael Cruz
# 24                                   Norman Solomon
# 25                                                👀
# 26                                         Samantha
# 27                                  Calibernication
# 28                               Eyðstein Borgardal
# 29   Wesley J Wiles #MMT Radical Environmentalist 🌹
# ..                                              ...
# 170                              Matthew G. Steel 🌺
# 171                        Yoshiyuki Mukudai Social
# 172                        Yoshiyuki Mukudai Social
# 173                                King Don Brother
# 174                            BelgiumForBernie🧇🍟🍫🍻
# 175                            BelgiumForBernie🧇🍟🍫🍻
# 176                            BelgiumForBernie🧇🍟🍫🍻
# 177                            BelgiumForBernie🧇🍟🍫🍻
# 178                        Yoshiyuki Mukudai Social
# 179                               Christopher Marra
# 180                            BelgiumForBernie🧇🍟🍫🍻
# 181                                  10 Wall Street
# 182                            BelgiumForBernie🧇🍟🍫🍻
# 183                                   Leslie Harman
# 184                            DJFlorek Photography
# 185                                  NoMiddleGround
# 186                                      Sunny Rain
# 187                    F.L.Y.M.E.N. Ministries Inc.
# 188                                  MimiMiller 420
# 189                            BelgiumForBernie🧇🍟🍫🍻
# 190                            BelgiumForBernie🧇🍟🍫🍻
# 191                            BelgiumForBernie🧇🍟🍫🍻
# 192                            BelgiumForBernie🧇🍟🍫🍻
# 193                            BelgiumForBernie🧇🍟🍫🍻
# 194                            BelgiumForBernie🧇🍟🍫🍻
# 195                            BelgiumForBernie🧇🍟🍫🍻
# 196                            BelgiumForBernie🧇🍟🍫🍻
# 197                            BelgiumForBernie🧇🍟🍫🍻
# 198                                   ɹoʇɐuǝʌou 💫🌹🔥
# 199     Seeking Peace Through Transformative Change
#
# [200 rows x 14 columns]

# %%
#Begin API Scrape - Day 2
listTweets2 = []

StartDt = today - DT.timedelta(days=6)
EndDt = DT.date.today() - DT.timedelta(days=5)
searchterm = '#feelthebern'
keyword = searchterm+' since:'+str(StartDt)+' until:'+str(EndDt)+' -filter:retweets'
NumTweets = 200

def get_tweets2(listTweets2, keyword, NumTweets):
    # Iterate through all tweets containing the given word, api search mode
    for tweet in tweepy.Cursor(api.search, q=keyword).items(NumTweets):
        # Add tweets in this format
        dict_ = {'Screen_Name': tweet.user.screen_name,
                'User_Name': tweet.user.name,
                'Tweet_Created_At': str(DT_from_utc_to_local(tweet.created_at)),
                'Tweet_Text': tweet.text,
                'Hashtags': tweet.entities.get('hashtags'), #How? - get only hashtag text
                'User_Location': str(tweet.user.location),
                'Tweet_Coordinates': str(tweet.coordinates),
                'Tweet_Place': str(tweet.place),
                'Retweet_Count': str(tweet.retweet_count),
                'Retweeted': str(tweet.retweeted),
                'Favorite_Count': str(tweet.favorite_count),
                'Favorited': str(tweet.favorited),
                'Replied': str(tweet.in_reply_to_status_id_str),
                'Tweet_URL': tweet.entities.get('urls') #How? - get only expanded url?
                }
        listTweets2.append(dict_)   
    return listTweets2

get_tweets2(listTweets2, keyword, NumTweets)

# %%
df2 = pd.DataFrame.from_dict(listTweets2, orient='columns')

# %%
#Begin API Scrape - Day 3
listTweets3 = []

StartDt = today - DT.timedelta(days=5)
EndDt = DT.date.today() - DT.timedelta(days=4)
searchterm = '#feelthebern'
keyword = searchterm+' since:'+str(StartDt)+' until:'+str(EndDt)+' -filter:retweets'
NumTweets = 200

def get_tweets3(listTweets3, keyword, NumTweets):
    # Iterate through all tweets containing the given word, api search mode
    for tweet in tweepy.Cursor(api.search, q=keyword).items(NumTweets):
        # Add tweets in this format
        dict_ = {'Screen_Name': tweet.user.screen_name,
                'User_Name': tweet.user.name,
                'Tweet_Created_At': str(DT_from_utc_to_local(tweet.created_at)),
                'Tweet_Text': tweet.text,
                'Hashtags': tweet.entities.get('hashtags'), #How? - get only hashtag text
                'User_Location': str(tweet.user.location),
                'Tweet_Coordinates': str(tweet.coordinates),
                'Tweet_Place': str(tweet.place),
                'Retweet_Count': str(tweet.retweet_count),
                'Retweeted': str(tweet.retweeted),
                'Favorite_Count': str(tweet.favorite_count),
                'Favorited': str(tweet.favorited),
                'Replied': str(tweet.in_reply_to_status_id_str),
                'Tweet_URL': tweet.entities.get('urls') #How? - get only expanded url?
                }
        listTweets3.append(dict_)   
    return listTweets3

get_tweets3(listTweets3, keyword, NumTweets)

# %%
df3 = pd.DataFrame.from_dict(listTweets3, orient='columns')

# %%
#Begin API Scrape - Day 4
listTweets4 = []

StartDt = today - DT.timedelta(days=4)
EndDt = DT.date.today() - DT.timedelta(days=3)
searchterm = '#feelthebern'
keyword = searchterm+' since:'+str(StartDt)+' until:'+str(EndDt)+' -filter:retweets'
NumTweets = 200

def get_tweets4(listTweets4, keyword, NumTweets):
    # Iterate through all tweets containing the given word, api search mode
    for tweet in tweepy.Cursor(api.search, q=keyword).items(NumTweets):
        # Add tweets in this format
        dict_ = {'Screen_Name': tweet.user.screen_name,
                'User_Name': tweet.user.name,
                'Tweet_Created_At': str(DT_from_utc_to_local(tweet.created_at)),
                'Tweet_Text': tweet.text,
                'Hashtags': tweet.entities.get('hashtags'), #How? - get only hashtag text
                'User_Location': str(tweet.user.location),
                'Tweet_Coordinates': str(tweet.coordinates),
                'Tweet_Place': str(tweet.place),
                'Retweet_Count': str(tweet.retweet_count),
                'Retweeted': str(tweet.retweeted),
                'Favorite_Count': str(tweet.favorite_count),
                'Favorited': str(tweet.favorited),
                'Replied': str(tweet.in_reply_to_status_id_str),
                'Tweet_URL': tweet.entities.get('urls') #How? - get only expanded url?
                }
        listTweets4.append(dict_)   
    return listTweets4

get_tweets4(listTweets4, keyword, NumTweets)

# %%
df4 = pd.DataFrame.from_dict(listTweets4, orient='columns')

# %%
#Begin API Scrape - Day 5
listTweets5 = []

StartDt = today - DT.timedelta(days=3)
EndDt = DT.date.today() - DT.timedelta(days=2)
searchterm = '#feelthebern'
keyword = searchterm+' since:'+str(StartDt)+' until:'+str(EndDt)+' -filter:retweets'
NumTweets = 200

def get_tweets5(listTweets5, keyword, NumTweets):
    # Iterate through all tweets containing the given word, api search mode
    for tweet in tweepy.Cursor(api.search, q=keyword).items(NumTweets):
        # Add tweets in this format
        dict_ = {'Screen_Name': tweet.user.screen_name,
                'User_Name': tweet.user.name,
                'Tweet_Created_At': str(DT_from_utc_to_local(tweet.created_at)),
                'Tweet_Text': tweet.text,
                'Hashtags': tweet.entities.get('hashtags'), #How? - get only hashtag text
                'User_Location': str(tweet.user.location),
                'Tweet_Coordinates': str(tweet.coordinates),
                'Tweet_Place': str(tweet.place),
                'Retweet_Count': str(tweet.retweet_count),
                'Retweeted': str(tweet.retweeted),
                'Favorite_Count': str(tweet.favorite_count),
                'Favorited': str(tweet.favorited),
                'Replied': str(tweet.in_reply_to_status_id_str),
                'Tweet_URL': tweet.entities.get('urls') #How? - get only expanded url?
                }
        listTweets5.append(dict_)   
    return listTweets5

get_tweets5(listTweets5, keyword, NumTweets)

# %%
df5 = pd.DataFrame.from_dict(listTweets5, orient='columns')

# %%
#Begin API Scrape - Day 6
listTweets6 = []

StartDt = today - DT.timedelta(days=2)
EndDt = DT.date.today() - DT.timedelta(days=1)
searchterm = '#feelthebern'
keyword = searchterm+' since:'+str(StartDt)+' until:'+str(EndDt)+' -filter:retweets'
NumTweets = 200

def get_tweets6(listTweets6, keyword, NumTweets):
    # Iterate through all tweets containing the given word, api search mode
    for tweet in tweepy.Cursor(api.search, q=keyword).items(NumTweets):
        # Add tweets in this format
        dict_ = {'Screen_Name': tweet.user.screen_name,
                'User_Name': tweet.user.name,
                'Tweet_Created_At': str(DT_from_utc_to_local(tweet.created_at)),
                'Tweet_Text': tweet.text,
                'Hashtags': tweet.entities.get('hashtags'), #How? - get only hashtag text
                'User_Location': str(tweet.user.location),
                'Tweet_Coordinates': str(tweet.coordinates),
                'Tweet_Place': str(tweet.place),
                'Retweet_Count': str(tweet.retweet_count),
                'Retweeted': str(tweet.retweeted),
                'Favorite_Count': str(tweet.favorite_count),
                'Favorited': str(tweet.favorited),
                'Replied': str(tweet.in_reply_to_status_id_str),
                'Tweet_URL': tweet.entities.get('urls') #How? - get only expanded url?
                }
        listTweets6.append(dict_)   
    return listTweets6

get_tweets6(listTweets6, keyword, NumTweets)

# %%
df6 = pd.DataFrame.from_dict(listTweets6, orient='columns')

# %%
#Begin API Scrape - Day 7
listTweets7 = []

StartDt = today - DT.timedelta(days=1)
EndDt = DT.date.today() - DT.timedelta(days=0)
searchterm = '#feelthebern'
keyword = searchterm+' since:'+str(StartDt)+' until:'+str(EndDt)+' -filter:retweets'
NumTweets = 200

def get_tweets7(listTweets7, keyword, NumTweets):
    # Iterate through all tweets containing the given word, api search mode
    for tweet in tweepy.Cursor(api.search, q=keyword).items(NumTweets):
        # Add tweets in this format
        dict_ = {'Screen_Name': tweet.user.screen_name,
                'User_Name': tweet.user.name,
                'Tweet_Created_At': str(DT_from_utc_to_local(tweet.created_at)),
                'Tweet_Text': tweet.text,
                'Hashtags': tweet.entities.get('hashtags'), #How? - get only hashtag text
                'User_Location': str(tweet.user.location),
                'Tweet_Coordinates': str(tweet.coordinates),
                'Tweet_Place': str(tweet.place),
                'Retweet_Count': str(tweet.retweet_count),
                'Retweeted': str(tweet.retweeted),
                'Favorite_Count': str(tweet.favorite_count),
                'Favorited': str(tweet.favorited),
                'Replied': str(tweet.in_reply_to_status_id_str),
                'Tweet_URL': tweet.entities.get('urls') #How? - get only expanded url?
                }
        listTweets7.append(dict_)   
    return listTweets7

get_tweets7(listTweets7, keyword, NumTweets)

# %%
df7 = pd.DataFrame.from_dict(listTweets7, orient='columns')

# %%
twitter_data = pd.concat([df1, df2, df3, df4, df5, df6, df7], axis=0)

# %%
#Add city coordinates to dataset
key = creds['key']
geocoder = OpenCageGeocode(key)

location = twitter_data[['User_Location']].drop_duplicates()
location = location.reset_index()
Var_Empty = location['User_Location'] != ''
location = location[conjunction(Var_Empty)]
#Begin getting coordinates
list_lat = []
list_long = []
for index, row in location.iterrows():
    try:
        city = row['User_Location']
        query = str(city)
        results = geocoder.geocode(query)
        lat = results[0]['geometry']['lat']
        long = results[0]['geometry']['lng']
        list_lat.append(lat)
        list_long.append(long)
    except:
        list_lat.append(0)
        list_long.append(0)

location['lat'] = list_lat
location['long'] = list_long
twitter_data = twitter_data.merge(location, left_on='User_Location', right_on='User_Location')
twitter_data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-643206a306e5> in <module>
#       3 geocoder = OpenCageGeocode(key)
#       4
# ----> 5 location = twitter_data[['User_Location']].drop_duplicates()
#       6 location = location.reset_index()
#       7 Var_Empty = location['User_Location'] != ''
#
# NameError: name 'twitter_data' is not defined

# %%
# Var_0 = twitter_data['lat'] != 0
# twitter_data = twitter_data[conjunction(Var_0)]
# Twitter_data = twitter_data[['Screen_Name','User_Name','Tweet_Text','Hashtags','Tweet_Created_At','Favorite_Count','Retweet_Count','Tweet_URL','lat','long']]
# twitter_data['keyword'] = searchterm
records = json.loads(twitter_data.T.to_json()).values()

# %%
#Connect to Mongo DB Atlas
import pymongo
from pymongo import MongoClient

client = pymongo.MongoClient("mongodb+srv://vgalst:akopova123@tweetering-giclm.mongodb.net/test?retryWrites=true&w=majority")
db = client.twitter
collection = db['hashtagdata']

# %%
collection.insert_many(records)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-4f3694203487> in <module>
# ----> 1 collection.insert_many(records)
#
# NameError: name 'collection' is not defined

# %%
twitter_data = pd.read_csv("export_dataframe_4.csv") 
#export_csv = twitter_data.to_csv (r'/Users/macbook/Desktop/Data-Program-Files/Group-Projects/Project-3/export_dataframe_4.csv', index = None, header=True) #Don't forget to add '.csv' at the end of the path

# %%
listTweets = []
x = 7
y = 6
while x > -1:
    today = DT.date.today()
    StartDt = today - DT.timedelta(days=x)
    EndDt = DT.date.today() - DT.timedelta(days=y)
    searchterm = '#keepamericagreat'
    keyword = searchterm+' since:'+str(StartDt)+' until:'+str(EndDt)+' -filter:retweets'
    NumTweets = 200
    def get_tweets(listTweets, keyword, NumTweets):
    # Iterate through all tweets containing the given word, api search mode
        for tweet in tweepy.Cursor(api.search, q=keyword).items(NumTweets):
        # Add tweets in this format
            dict_ = {'Screen_Name': tweet.user.screen_name,
                    'User_Name': tweet.user.name,
                    'Tweet_Created_At': str(DT_from_utc_to_local(tweet.created_at)),
                    'Tweet_Text': tweet.text,
                    'Hashtags': tweet.entities.get('hashtags'), #How? - get only hashtag text
                    'User_Location': str(tweet.user.location),
                    'Tweet_Coordinates': str(tweet.coordinates),
                    'Tweet_Place': str(tweet.place),
                    'Retweet_Count': str(tweet.retweet_count),
                    'Retweeted': str(tweet.retweeted),
                    'Favorite_Count': str(tweet.favorite_count),
                    'Favorited': str(tweet.favorited),
                    'Replied': str(tweet.in_reply_to_status_id_str),
                    'Tweet_URL': tweet.entities.get('urls') #How? - get only expanded url?
                    }
            listTweets.append(dict_)
        return listTweets
#     get_tweets(listTweets, keyword, NumTweets)
    x = x - 1
    y = y - 1
    df  = pd.DataFrame(listTweets)
    df_all = pd.DataFrame()
    df_all = pd.concat([df_all, df])

# %%
#Add city coordinates to dataset
twitter_data = df_all.reset_index()
key = creds['key']
geocoder = OpenCageGeocode(key)
location = twitter_data[['User_Location']].drop_duplicates()
location = location.reset_index()
Var_Empty = location['User_Location'] != ''
location = location[conjunction(Var_Empty)]
#Begin getting coordinates
list_lat = []
list_long = []
for index, row in location.iterrows():
    try:
        city = row['User_Location']
        query = str(city)
        results = geocoder.geocode(query)
        lat = results[0]['geometry']['lat']
        long = results[0]['geometry']['lng']
        list_lat.append(lat)
        list_long.append(long)
    except:
        list_lat.append(0)
        list_long.append(0)
location['lat'] = list_lat
location['long'] = list_long
twitter_data = twitter_data.merge(location, left_on='User_Location', right_on='User_Location')
twitter_data.head()
# Out:
# From cffi callback <function _verify_callback at 0x0000022ECE4922F0>:
# Traceback (most recent call last):
#   File "C:\Users\angy4\Anaconda3\lib\site-packages\OpenSSL\SSL.py", line 306, in wrapper
#     @wraps(callback)
# KeyboardInterrupt
