# %%
#Connect to Mongo DB Atlas
import pymongo
from pymongo import MongoClient

deployment_matt = "mongodb+srv://thrum-rw:Skipshot1@thrumcluster-f2hkj.mongodb.net/test?retryWrites=true&w=majority"
deployment_victor = "mongodb+srv://vgalst:akopova123@tweetering-giclm.mongodb.net/test?retryWrites=true&w=majority"
testing = "mongodb://localhost:27017/myDatabase"

client = pymongo.MongoClient(deployment_victor)
db = client.twitter
serverStatusResult=db.command("serverStatus")
if serverStatusResult:
    print("""
Connection to MongoDB was successful
    """)
    print("The following collections are available: ", db.list_collection_names())
# Out:
# Connection to MongoDB was successful
#
# The following collections are available:  ['userdata', 'hashtagdata']

# %%
collection = db['hashtagdata']
sample_tweets = collection.find({}, {'_id': False}).limit(10)

from pprint import pprint
for tweet in sample_tweets:
    pprint(tweet)
# Out:
# {'Favorite_Count': 0,
#  'Favorited': False,
#  'Hashtags': "[{'text': 'FeelTheBern', 'indices': [51, 63]}, {'text': "
#              "'Bernie2020', 'indices': [64, 75]}, {'text': 'TooFarLeft', "
#              "'indices': [76, 87]}, {'text': 'BlueWave', 'indices': [88, 97]}]",
#  'Replied': '1196284986225094656',
#  'Retweet_Count': 0,
#  'Retweeted': False,
#  'Screen_Name': 'diannereads',
#  'Tweet_Coordinates': 'None',
#  'Tweet_Created_At': '2019-11-18 15:54:41',
#  'Tweet_Place': 'None',
#  'Tweet_Text': '@davidsirota @BernieSanders It was a great weekend '
#                '#FeelTheBern #Bernie2020 #TooFarLeft #BlueWave '
#                'https://t.co/siUOOu5FYu',
#  'Tweet_URL': '[]',
#  'User_Location': 'United States',
#  'User_Name': 'D',
#  'index': 1,
#  'keyword': '#feelthebern',
#  'lat': 39.7837304,
#  'long': -100.4458825}
# {'Favorite_Count': 0,
#  'Favorited': False,
#  'Hashtags': "[{'text': 'government', 'indices': [89, 100]}]",
#  'Replied': '1196555011418927106',
#  'Retweet_Count': 0,
#  'Retweeted': False,
#  'Screen_Name': 'sgtcrypto99',
#  'Tweet_Coordinates': 'None',
#  'Tweet_Created_At': '2019-11-18 14:44:13',
#  'Tweet_Place': 'None',
#  'Tweet_Text': '@BernieSanders How is “taxing” a company more going to stop '
#                'the “ravenous beast” aka the #government stop spending?… '
#                'https://t.co/gjD6qll2h3',
#  'Tweet_URL': "[{'url': 'https://t.co/gjD6qll2h3', 'expanded_url': "
#               "'https://twitter.com/i/web/status/1196559765419245568', "
#               "'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, "
#               '140]}]',
#  'User_Location': 'United States',
#  'User_Name': 'Sgt.Crypto',
#  'index': 1,
#  'keyword': '#feelthebern',
#  'lat': 39.7837304,
#  'long': -100.4458825}
# {'Favorite_Count': 1,
#  'Favorited': False,
#  'Hashtags': "[{'text': 'FeelTheBern', 'indices': [0, 12]}]",
#  'Replied': 'None',
#  'Retweet_Count': 1,
#  'Retweeted': False,
#  'Screen_Name': 'Nite_Colors',
#  'Tweet_Coordinates': 'None',
#  'Tweet_Created_At': '2019-11-18 11:43:54',
#  'Tweet_Place': 'None',
#  'Tweet_Text': '#FeelTheBern https://t.co/RJcLY9CkVk',
#  'Tweet_URL': "[{'url': 'https://t.co/RJcLY9CkVk', 'expanded_url': "
#               "'https://twitter.com/thehill/status/1196241884944973824', "
#               "'display_url': 'twitter.com/thehill/status…', 'indices': [13, "
#               '36]}]',
#  'User_Location': 'United States',
#  'User_Name': 'Brent ♔ ♕ ♗ ♘ ♙',
#  'index': 1,
#  'keyword': '#feelthebern',
#  'lat': 39.7837304,
#  'long': -100.4458825}
# {'Favorite_Count': 17,
#  'Favorited': False,
#  'Hashtags': "[{'text': 'M4A', 'indices': [60, 64]}]",
#  'Replied': '1196437110519152642',
#  'Retweet_Count': 0,
#  'Retweeted': False,
#  'Screen_Name': 'CathiZhoomin',
#  'Tweet_Coordinates': 'None',
#  'Tweet_Created_At': '2019-11-18 08:06:08',
#  'Tweet_Place': 'None',
#  'Tweet_Text': '@timjacobwise What’s with all this “No We Can’t” BS. Taking '
#                '#M4A off the table from the get gets you nothing. We’ve… '
#                'https://t.co/2zFHxXkaLp',
#  'Tweet_URL': "[{'url': 'https://t.co/2zFHxXkaLp', 'expanded_url': "
#               "'https://twitter.com/i/web/status/1196459581972664321', "
#               "'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, "
#               '140]}]',
#  'User_Location': 'United States',
#  'User_Name': 'Cathi Zhoomin Rotan',
#  'index': 1,
#  'keyword': '#feelthebern',
#  'lat': 39.7837304,
#  'long': -100.4458825}
# {'Favorite_Count': 0,
#  'Favorited': False,
#  'Hashtags': "[{'text': 'Biden2020', 'indices': [0, 10]}]",
#  'Replied': 'None',
#  'Retweet_Count': 0,
#  'Retweeted': False,
#  'Screen_Name': 'BHPanimalwatch',
#  'Tweet_Coordinates': 'None',
#  'Tweet_Created_At': '2019-11-18 07:43:03',
#  'Tweet_Place': 'None',
#  'Tweet_Text': '#Biden2020 is all about appeasing non existent "moderate '
#                'Republican voters" just like Hillary Clinton\'s losing stra… '
#                'https://t.co/SAjMy3HbHn',
#  'Tweet_URL': "[{'url': 'https://t.co/SAjMy3HbHn', 'expanded_url': "
#               "'https://twitter.com/i/web/status/1196453775210352640', "
#               "'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, "
#               '140]}]',
#  'User_Location': 'United States',
#  'User_Name': 'BHP Animal Watch',
#  'index': 1,
#  'keyword': '#feelthebern',
#  'lat': 39.7837304,
#  'long': -100.4458825}
# {'Favorite_Count': 0,
#  'Favorited': False,
#  'Hashtags': "[{'text': 'ChangeAmerica', 'indices': [75, 89]}, {'text': "
#              "'Democracy', 'indices': [105, 115]}]",
#  'Replied': '1196327835423539202',
#  'Retweet_Count': 0,
#  'Retweeted': False,
#  'Screen_Name': 'BHPanimalwatch',
#  'Tweet_Coordinates': 'None',
#  'Tweet_Created_At': '2019-11-18 05:35:16',
#  'Tweet_Place': 'None',
#  'Tweet_Text': '@Noahpinion And the common denominator is...\n'
#                "Yes, US Foreign Policy. Let's #ChangeAmerica. Let's support "
#                '#Democracy… https://t.co/ddjtcgpqgx',
#  'Tweet_URL': "[{'url': 'https://t.co/ddjtcgpqgx', 'expanded_url': "
#               "'https://twitter.com/i/web/status/1196421615812255745', "
#               "'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, "
#               '140]}]',
#  'User_Location': 'United States',
#  'User_Name': 'BHP Animal Watch',
#  'index': 1,
#  'keyword': '#feelthebern',
#  'lat': 39.7837304,
#  'long': -100.4458825}
# {'Favorite_Count': 0,
#  'Favorited': False,
#  'Hashtags': "[{'text': 'FeelTheBern', 'indices': [0, 12]}, {'text': "
#              "'ChangeAmerica', 'indices': [13, 27]}, {'text': 'Bernie2020', "
#              "'indices': [28, 39]}]",
#  'Replied': 'None',
#  'Retweet_Count': 0,
#  'Retweeted': False,
#  'Screen_Name': 'BHPanimalwatch',
#  'Tweet_Coordinates': 'None',
#  'Tweet_Created_At': '2019-11-18 05:31:51',
#  'Tweet_Place': 'None',
#  'Tweet_Text': '#FeelTheBern #ChangeAmerica #Bernie2020 '
#                'https://t.co/jTgVm7Yeja',
#  'Tweet_URL': "[{'url': 'https://t.co/jTgVm7Yeja', 'expanded_url': "
#               "'https://twitter.com/venanalysis/status/1196255398283685888', "
#               "'display_url': 'twitter.com/venanalysis/st…', 'indices': [40, "
#               '63]}]',
#  'User_Location': 'United States',
#  'User_Name': 'BHP Animal Watch',
#  'index': 1,
#  'keyword': '#feelthebern',
#  'lat': 39.7837304,
#  'long': -100.4458825}
# {'Favorite_Count': 0,
#  'Favorited': False,
#  'Hashtags': "[{'text': 'FeelTheBern', 'indices': [49, 61]}, {'text': "
#              "'Bernie2020', 'indices': [62, 73]}, {'text': "
#              "'berniecanplayball', 'indices': [74, 92]}, {'text': 'TeamBlue', "
#              "'indices': [93, 102]}]",
#  'Replied': '1196220761842700288',
#  'Retweet_Count': 0,
#  'Retweeted': False,
#  'Screen_Name': 'terrimateer',
#  'Tweet_Coordinates': 'None',
#  'Tweet_Created_At': '2019-11-18 05:28:31',
#  'Tweet_Place': 'Place(_api=<tweepy.api.API object at 0x1055c5f28>, '
#                 "id='94965b2c45386f87', "
#                 "url='https://api.twitter.com/1.1/geo/id/94965b2c45386f87.json', "
#                 "place_type='admin', name='New York', full_name='New York, "
#                 "USA', country_code='US', country='United States', "
#                 'contained_within=[], '
#                 'bounding_box=BoundingBox(_api=<tweepy.api.API object at '
#                 "0x1055c5f28>, type='Polygon', coordinates=[[[-79.76259, "
#                 '40.477383], [-71.777492, 40.477383], [-71.777492, 45.015851], '
#                 '[-79.76259, 45.015851]]]), attributes={})',
#  'Tweet_Text': '@fshakir @BernieSanders Best team player we got! #FeelTheBern '
#                '#Bernie2020 #berniecanplayball #TeamBlue',
#  'Tweet_URL': '[]',
#  'User_Location': 'United States',
#  'User_Name': 'Terri Mateer',
#  'index': 1,
#  'keyword': '#feelthebern',
#  'lat': 39.7837304,
#  'long': -100.4458825}
# {'Favorite_Count': 9,
#  'Favorited': False,
#  'Hashtags': "[{'text': 'TeamBernie', 'indices': [5, 16]}, {'text': 'NotMeUs', "
#              "'indices': [33, 41]}]",
#  'Replied': 'None',
#  'Retweet_Count': 2,
#  'Retweeted': False,
#  'Screen_Name': 'LovesTheBern',
#  'Tweet_Coordinates': 'None',
#  'Tweet_Created_At': '2019-11-19 12:27:55',
#  'Tweet_Place': 'None',
#  'Tweet_Text': 'Dear #TeamBernie: Please put the #NotMeUs graphic on a mug. I '
#                "know it's on a koozie, but it would be fantastic on a… "
#                'https://t.co/F1l0UzmCtO',
#  'Tweet_URL': "[{'url': 'https://t.co/F1l0UzmCtO', 'expanded_url': "
#               "'https://twitter.com/i/web/status/1196887852824444928', "
#               "'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, "
#               '140]}]',
#  'User_Location': 'United States',
#  'User_Name': 'Veronica Serves Tea',
#  'index': 1,
#  'keyword': '#feelthebern',
#  'lat': 39.7837304,
#  'long': -100.4458825}
# {'Favorite_Count': 0,
#  'Favorited': False,
#  'Hashtags': '[]',
#  'Replied': '1196848706567524364',
#  'Retweet_Count': 0,
#  'Retweeted': False,
#  'Screen_Name': 'ppprogressive',
#  'Tweet_Coordinates': 'None',
#  'Tweet_Created_At': '2019-11-19 09:52:22',
#  'Tweet_Place': 'None',
#  'Tweet_Text': 'that it is about time America finally has universal '
#                'healthcare, he wa seeing very vague because he stated he '
#                'wasn’t… https://t.co/j20PLOWTlq',
#  'Tweet_URL': "[{'url': 'https://t.co/j20PLOWTlq', 'expanded_url': "
#               "'https://twitter.com/i/web/status/1196848707850899456', "
#               "'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, "
#               '140]}]',
#  'User_Location': 'United States',
#  'User_Name': 'Feel The Bern🔥',
#  'index': 1,
#  'keyword': '#feelthebern',
#  'lat': 39.7837304,
#  'long': -100.4458825}

# %%
collection = db['userdata']
sample_tweets = collection.find({}, {'_id': False}).limit(10)

from pprint import pprint
for tweet in sample_tweets:
    pprint(tweet)
# Out:
# {'Favorite_Count': '41053',
#  'Hashtags': [],
#  'Retweet_Count': '11846',
#  'Screen_Name': 'realDonaldTrump',
#  'Tweet_Coordinates': 'None',
#  'Tweet_Created_At': '2019-11-30 17:28:18',
#  'Tweet_Place': 'None',
#  'Tweet_Text': '“Schiff’s impeachment hearings wasting time when Congress must '
#                'do real work” https://t.co/4lb9bWrVRL',
#  'Tweet_URL': [{'display_url': 'nypost.com/2019/11/21/sch…',
#                 'expanded_url': 'https://nypost.com/2019/11/21/schiffs-impeachment-hearings-wasting-time-when-congress-must-do-real-work/',
#                 'indices': [77, 100],
#                 'url': 'https://t.co/4lb9bWrVRL'}],
#  'User_Location': 'Washington, DC',
#  'User_Name': 'Donald J. Trump',
#  'keyword': '@realDonaldTrump',
#  'lat': 38.8948932,
#  'long': -77.0365529}
# {'Favorite_Count': '26055',
#  'Hashtags': [],
#  'Retweet_Count': '7839',
#  'Screen_Name': 'realDonaldTrump',
#  'Tweet_Coordinates': 'None',
#  'Tweet_Created_At': '2019-11-30 17:26:21',
#  'Tweet_Place': 'None',
#  'Tweet_Text': '“Trump did nothing impeachable, day-by-day review of all '
#                'impeachment hearing testimony shows” @GreggJarrett '
#                'https://t.co/QbFeEmWkTB',
#  'Tweet_URL': [{'display_url': 'foxnews.com/opinion/gregg-…',
#                 'expanded_url': 'https://www.foxnews.com/opinion/gregg-jarrett-trump-did-nothing-impeachable-day-by-day-review-of-all-impeachment-hearing-testimony-shows',
#                 'indices': [108, 131],
#                 'url': 'https://t.co/QbFeEmWkTB'}],
#  'User_Location': 'Washington, DC',
#  'User_Name': 'Donald J. Trump',
#  'keyword': '@realDonaldTrump',
#  'lat': 38.8948932,
#  'long': -77.0365529}
# {'Favorite_Count': '28130',
#  'Hashtags': [],
#  'Retweet_Count': '8473',
#  'Screen_Name': 'realDonaldTrump',
#  'Tweet_Coordinates': 'None',
#  'Tweet_Created_At': '2019-11-30 17:24:34',
#  'Tweet_Place': 'None',
#  'Tweet_Text': "“Sen. Tim Scott Says Trump 'Innocent,' 'No Way' Senate "
#                'Convicts” https://t.co/P6ONkI8n0P',
#  'Tweet_URL': [{'display_url': 'breitbart.com/politics/2019/…',
#                 'expanded_url': 'https://www.breitbart.com/politics/2019/11/25/nolte-sen-tim-scott-says-trump-innocent-no-way-senate-convicts/',
#                 'indices': [65, 88],
#                 'url': 'https://t.co/P6ONkI8n0P'}],
#  'User_Location': 'Washington, DC',
#  'User_Name': 'Donald J. Trump',
#  'keyword': '@realDonaldTrump',
#  'lat': 38.8948932,
#  'long': -77.0365529}
# {'Favorite_Count': '0',
#  'Hashtags': [],
#  'Retweet_Count': '9674',
#  'Screen_Name': 'realDonaldTrump',
#  'Tweet_Coordinates': 'None',
#  'Tweet_Created_At': '2019-11-30 15:51:30',
#  'Tweet_Place': 'None',
#  'Tweet_Text': 'RT @WhiteHouse: "The men and women of our military are totally '
#                'loyal to our country. And every day I am President, America '
#                'will always be t…',
#  'Tweet_URL': [],
#  'User_Location': 'Washington, DC',
#  'User_Name': 'Donald J. Trump',
#  'keyword': '@realDonaldTrump',
#  'lat': 38.8948932,
#  'long': -77.0365529}
# {'Favorite_Count': '0',
#  'Hashtags': [],
#  'Retweet_Count': '9884',
#  'Screen_Name': 'realDonaldTrump',
#  'Tweet_Coordinates': 'None',
#  'Tweet_Created_At': '2019-11-30 15:51:01',
#  'Tweet_Place': 'None',
#  'Tweet_Text': "RT @GOPChairwoman: Just 8 work days left on Congress' calendar "
#                'this year.\n'
#                '\n'
#                'Instead of attacking @realDonaldTrump, Pelosi should work '
#                'across…',
#  'Tweet_URL': [],
#  'User_Location': 'Washington, DC',
#  'User_Name': 'Donald J. Trump',
#  'keyword': '@realDonaldTrump',
#  'lat': 38.8948932,
#  'long': -77.0365529}
# {'Favorite_Count': '35864',
#  'Hashtags': [],
#  'Retweet_Count': '9101',
#  'Screen_Name': 'realDonaldTrump',
#  'Tweet_Coordinates': 'None',
#  'Tweet_Created_At': '2019-11-30 15:50:36',
#  'Tweet_Place': 'None',
#  'Tweet_Text': 'An incredible experience! https://t.co/n6BNQY6dIx',
#  'Tweet_URL': [{'display_url': 'twitter.com/whitehouse/sta…',
#                 'expanded_url': 'https://twitter.com/whitehouse/status/1200593444944654336',
#                 'indices': [26, 49],
#                 'url': 'https://t.co/n6BNQY6dIx'}],
#  'User_Location': 'Washington, DC',
#  'User_Name': 'Donald J. Trump',
#  'keyword': '@realDonaldTrump',
#  'lat': 38.8948932,
#  'long': -77.0365529}
# {'Favorite_Count': '0',
#  'Hashtags': [{'indices': [73, 79], 'text': 'USMCA'}],
#  'Retweet_Count': '9829',
#  'Screen_Name': 'realDonaldTrump',
#  'Tweet_Coordinates': 'None',
#  'Tweet_Created_At': '2019-11-30 15:48:06',
#  'Tweet_Place': 'None',
#  'Tweet_Text': 'RT @TeamTrump: One year ago today, President @realDonaldTrump '
#                'signed the #USMCA with Canada and Mexico.\n'
#                '\n'
#                "It now sits on Nancy Pelosi's desk…",
#  'Tweet_URL': [],
#  'User_Location': 'Washington, DC',
#  'User_Name': 'Donald J. Trump',
#  'keyword': '@realDonaldTrump',
#  'lat': 38.8948932,
#  'long': -77.0365529}
# {'Favorite_Count': '0',
#  'Hashtags': [{'indices': [66, 72], 'text': 'USMCA'}],
#  'Retweet_Count': '12757',
#  'Screen_Name': 'realDonaldTrump',
#  'Tweet_Coordinates': 'None',
#  'Tweet_Created_At': '2019-11-30 15:47:15',
#  'Tweet_Place': 'None',
#  'Tweet_Text': 'RT @VP: One year ago today, President @realDonaldTrump signed '
#                'the #USMCA. While this Administration works FOR the American '
#                'People, Speaker…',
#  'Tweet_URL': [],
#  'User_Location': 'Washington, DC',
#  'User_Name': 'Donald J. Trump',
#  'keyword': '@realDonaldTrump',
#  'lat': 38.8948932,
#  'long': -77.0365529}
# {'Favorite_Count': '0',
#  'Hashtags': [],
#  'Retweet_Count': '9169',
#  'Screen_Name': 'realDonaldTrump',
#  'Tweet_Coordinates': 'None',
#  'Tweet_Created_At': '2019-11-30 15:45:57',
#  'Tweet_Place': 'None',
#  'Tweet_Text': 'RT @VP: President @realDonaldTrump’s deregulatory agenda '
#                'unleashed American ingenuity and we are on path to becoming '
#                'not just energy indepe…',
#  'Tweet_URL': [],
#  'User_Location': 'Washington, DC',
#  'User_Name': 'Donald J. Trump',
#  'keyword': '@realDonaldTrump',
#  'lat': 38.8948932,
#  'long': -77.0365529}
# {'Favorite_Count': '0',
#  'Hashtags': [],
#  'Retweet_Count': '3901',
#  'Screen_Name': 'realDonaldTrump',
#  'Tweet_Coordinates': 'None',
#  'Tweet_Created_At': '2019-11-30 15:45:19',
#  'Tweet_Place': 'None',
#  'Tweet_Text': "RT @WattersWorld: . @realDonaldTrump won't get the nomination, "
#                "Trump won't win, Stock Market will tank, Russia "
#                'Collusion...These are the st…',
#  'Tweet_URL': [],
#  'User_Location': 'Washington, DC',
#  'User_Name': 'Donald J. Trump',
#  'keyword': '@realDonaldTrump',
#  'lat': 38.8948932,
#  'long': -77.0365529}
